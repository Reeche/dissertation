# %%
import sys
from collections import defaultdict
import matplotlib.pyplot as plt
from learning_models import ParameterOptimizer, ModelRunner, models
from modified_mouselab import reward_val, normal_reward_val
from learning_utils import string_to_bool, pickle_load, pickle_save, \
    get_normalized_features, Participant, create_dir, rows_mean
from sequence_utils import get_termination_mers
import pyabc
import logging
import itertools
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
#models = [0, 1, 64, 65, 576, 577, 640, 641, 1728, 1729, 1824, 1825, 2020, 2021, 2022, 2023]
models = list(range(3216))
control_pids = [1, 2, 6, 9, 11, 14, 18, 21, 24, 27, 37, 38, 44, 50, 55, 56, 58, 66, 76, 79, 85, 89, 90, 98, 99,
                100, 104, 111, 113, 118, 119, 123, 126, 129, 139, 142, 144, 153, 154]
obj = "mer_performance_error"
for model in models[:1]:
    print(model)
    data = pd.DataFrame()
    for pid in control_pids[:1]:
        try:
            d = pickle_load(f"results/model_performance_error/{pid}_{obj}_{model}.pkl")
            data = data.append(d, ignore_index=True)
            print(d)
        except Exception as e:
            print(e)
            continue
    #plt.figure()
    #ax = sns.lineplot(x="x", y="y", hue = "algo", data=data)
    #plt.title(model)
    #plt.legend()
    #plt.savefig(f"results/model_plots/{model}.png")
    #plt.close()
# Out:
# 0
#       x     y         algo
# 0     1  48.0         algo
# 1     2  48.0         algo
# 2     3  24.0         algo
# 3     4  24.0         algo
# 4     5  48.0         algo
# ..   ..   ...          ...
# 325  26  52.0  participant
# 326  27  52.0  participant
# 327  28  48.0  participant
# 328  29  48.0  participant
# 329  30  24.0  participant
#
# [330 rows x 3 columns]

# %%
models = list(range(3216))
control_pids = [1, 2, 6, 9, 11, 14, 18, 21, 24, 27, 37, 38, 44, 50, 55, 56, 58, 66, 76, 79, 85, 89, 90, 98, 99,
                100, 104, 111, 113, 118, 119, 123, 126, 129, 139, 142, 144, 153, 154]
n_trials = 30
obj = "mer_performance_error"
p_vals = []
m_vals = []
n_trials = 30
for i, pid in enumerate(control_pids):
    print(pid)
    data = pd.DataFrame()
    m_data = {}
    diffs = []
    j = 0
    for model in models:
        try:
            d = pickle_load(f"results/model_performance_error/{pid}_{obj}_{model}.pkl")
            data = data.append(d, ignore_index=True)
            mean_data = d.groupby(["algo", "x"]).mean()
            square = list(map(lambda x, y: (x-y)**2, mean_data['y']['algo'], mean_data['y']['participant']))
            p_val = mean_data['y']['participant'].values
            diff = np.sqrt(np.sum(square))
            diffs.append(diff)
            m_data[j] = mean_data
            j+=1
        except Exception as e:
            print(e)
            continue
    m_val = m_data[np.argmin(diffs)]["y"]["algo"].values
    if len(p_val) == n_trials and len(m_val) == n_trials:
        p_vals.append(p_val)
        m_vals.append(m_val)
#ax = sns.lineplot(x="x", y="y", hue = "algo", data=data)
plt.plot(range(1, len(p_val)+1), np.mean(p_vals, axis=0), label = "P") 
plt.plot(range(1, len(p_val)+1), np.mean(m_vals, axis=0), label = "M") 
plt.legend()
plt.show()
# Out:
# 1
# 2
# 6
# cannot concatenate object of type '<class 'numpy.float64'>'; only Series and DataFrame objs are valid
# cannot concatenate object of type '<class 'numpy.float64'>'; only Series and DataFrame objs are valid
# cannot concatenate object of type '<class 'numpy.float64'>'; only Series and DataFrame objs are valid
# cannot concatenate object of type '<class 'numpy.float64'>'; only Series and DataFrame objs are valid
# cannot concatenate object of type '<class 'numpy.float64'>'; only Series and DataFrame objs are valid
# cannot concatenate object of type '<class 'numpy.float64'>'; only Series and DataFrame objs are valid
# cannot concatenate object of type '<class 'numpy.float64'>'; only Series and DataFrame objs are valid
# cannot concatenate object of type '<class 'numpy.float64'>'; only Series and DataFrame objs are valid
# cannot concatenate object of type '<class 'numpy.float64'>'; only Series and DataFrame objs are valid
# cannot concatenate object of type '<class 'numpy.float64'>'; only Series and DataFrame objs are valid
# cannot concatenate object of type '<class 'numpy.float64'>'; only Series and DataFrame objs are valid
# cannot concatenate object of type '<class 'numpy.float64'>'; only Series and DataFrame objs are valid
# cannot concatenate object of type '<class 'numpy.float64'>'; only Series and DataFrame objs are valid
# cannot concatenate object of type '<class 'numpy.float64'>'; only Series and DataFrame objs are valid
# cannot concatenate object of type '<class 'numpy.float64'>'; only Series and DataFrame objs are valid
# cannot concatenate object of type '<class 'numpy.float64'>'; only Series and DataFrame objs are valid
# cannot concatenate object of type '<class 'numpy.float64'>'; only Series and DataFrame objs are valid
# 9
# cannot concatenate object of type '<class 'numpy.float64'>'; only Series and DataFrame objs are valid
# 11
# 14
# 18
# 21
# 24
# 27
# 37
# 38
# 44
# 50
# 55
# 56
# 58
# 66
# 76
# 79
# 85
# 89
# 90
# 98
# 99
# 100
# 104
# results/model_performance_error/104_mer_performance_error_2024.pkl not found.
# results/model_performance_error/104_mer_performance_error_2025.pkl not found.
# results/model_performance_error/104_mer_performance_error_2026.pkl not found.
# results/model_performance_error/104_mer_performance_error_2027.pkl not found.
# results/model_performance_error/104_mer_performance_error_2028.pkl not found.
# results/model_performance_error/104_mer_performance_error_2029.pkl not found.
# results/model_performance_error/104_mer_performance_error_2030.pkl not found.
# results/model_performance_error/104_mer_performance_error_2031.pkl not found.
# results/model_performance_error/104_mer_performance_error_2040.pkl not found.
# results/model_performance_error/104_mer_performance_error_2041.pkl not found.
# results/model_performance_error/104_mer_performance_error_2042.pkl not found.
# results/model_performance_error/104_mer_performance_error_2043.pkl not found.
# results/model_performance_error/104_mer_performance_error_2044.pkl not found.
# results/model_performance_error/104_mer_performance_error_2045.pkl not found.
# results/model_performance_error/104_mer_performance_error_2046.pkl not found.
# results/model_performance_error/104_mer_performance_error_2047.pkl not found.
# results/model_performance_error/104_mer_performance_error_2056.pkl not found.
# results/model_performance_error/104_mer_performance_error_2057.pkl not found.
# results/model_performance_error/104_mer_performance_error_2058.pkl not found.
# results/model_performance_error/104_mer_performance_error_2059.pkl not found.
# results/model_performance_error/104_mer_performance_error_2060.pkl not found.
# results/model_performance_error/104_mer_performance_error_2061.pkl not found.
# results/model_performance_error/104_mer_performance_error_2062.pkl not found.
# results/model_performance_error/104_mer_performance_error_2063.pkl not found.
# 111
# 113
# 118
# 119
# 123
# 126
# 129
# 139
# 142
# 144
# 153
# 154
# results/model_performance_error/154_mer_performance_error_2163.pkl not found.

# %%
from scipy.stats import norm
models = list(range(3216))
control_pids = [1, 2, 6, 9, 11, 14, 18, 21, 24, 27, 37, 38, 44, 50, 55, 56, 58, 66, 76, 79, 85, 89, 90, 98, 99,
                100, 104, 111, 113, 118, 119, 123, 126, 129, 139, 142, 144, 153, 154]
obj = "mer_performance_error"
sigma = 1
nlls = defaultdict(dict)
diffs = defaultdict(dict)
for i, pid in enumerate(control_pids):
    print(pid)
    data = pd.DataFrame()
    for model in models:
        try:
            d = pickle_load(f"results/model_performance_error/{pid}_{obj}_{model}.pkl")
            mean_data = d.groupby(["algo", "x"]).mean()
            algo_mean = mean_data['y']['algo'].values
            p_data = mean_data['y']['participant'].values
            diffs[pid][model] = np.sqrt(np.sum(algo_mean-p_data)**2)
            nlls[pid][model] = np.sum([-norm.logpdf(a_score, p_score, sigma) for a_score, p_score in zip(algo_mean, p_data)])
        except Exception as e:
            print(e)
            continue
# Out:
# 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-93-723c6255ee97> in <module>
#      12     for model in models:
#      13         try:
# ---> 14             d = pickle_load(f"results/model_performance_error/{pid}_{obj}_{model}.pkl")
#      15             mean_data = d.groupby(["algo", "x"]).mean()
#      16             algo_mean = mean_data['y']['algo'].values
#
# ~/modeling_mcl/python/learning_utils.py in pickle_load(file_path)
#      97             Unpickled object
#      98     """
# ---> 99     if not os.path.exists(file_path):
#     100         raise FileNotFoundError(f"{file_path} not found.")
#     101     obj = pickle.load(open(file_path, "rb"))
#
# /anaconda3/envs/cogtut/lib/python3.7/genericpath.py in exists(path)
#      17     """Test whether a path exists.  Returns False for broken symbolic links"""
#      18     try:
# ---> 19         os.stat(path)
#      20     except OSError:
#      21         return False
#
# KeyboardInterrupt:

# %%
M = pd.read_csv("rl_models.csv")

# %%
control_pids = [1, 2, 6, 9, 11, 14, 18, 21, 24, 27, 37, 38, 44, 50, 55, 56, 58, 66, 76, 79, 85, 89, 90, 98, 99,
                100, 104, 111, 113, 118, 119, 123, 126, 129, 139, 142, 144, 153, 154]

# %%
import operator

mod_control_pids = control_pids.copy()
for p in [79, 113, 126, 129]:
    mod_control_pids.remove(p)

algos = []
ps = []
def key_with_min_val(d):
    return min(d.items(), key=operator.itemgetter(1))[0]

def get_keys_with_min_aic(d):
    min_aic = min(d.values())
    min_indices = [i for i, aic in d.items() if aic <= min_aic + 2]
    return min_indices

n_trials=30
indices = {}
for pid in mod_control_pids:
    d = nlls[pid]
    min_key = key_with_min_val(d)
    indices[pid] = get_keys_with_min_aic(d)
    d = pickle_load(f"results/model_performance_error/{pid}_{obj}_{min_key}.pkl")
    mean_data = d.groupby(["algo", "x"]).mean()
    algo_mean = mean_data['y']['algo'].values
    p_data = mean_data['y']['participant'].values
    if len(algo_mean) == n_trials:
        algos.append(algo_mean)
        ps.append(p_data)
        #print(pid, M.iloc[min_key])
print(indices)
plt.plot(np.mean(algos, axis=0), label='Algo')
plt.plot(np.mean(ps, axis=0), label='Participant')
plt.legend()
plt.savefig("results/best_models.png")
# Out:
# {1: [1872, 2006], 2: [364, 478, 1814, 1892, 1907, 1939, 1950, 1969], 6: [1833], 9: [1108], 11: [641], 14: [9], 18: [1959], 21: [1059], 24: [1873], 27: [1899], 37: [645], 38: [1997], 44: [711], 50: [1893, 2001], 55: [1860, 1954], 56: [901], 58: [1948], 66: [4, 11, 14, 64, 75, 80, 84, 85, 95, 134, 136, 139, 150, 154, 158, 163, 277, 289, 319, 321, 334, 335, 342, 356, 374, 457, 465, 466, 468, 469, 493, 494, 521, 534, 538, 539, 541, 560, 644, 647, 654, 657, 658, 660, 669, 670, 705, 706, 708, 711, 713, 717, 718, 838, 842, 844, 845, 850, 854, 859, 860, 862, 901, 903, 905, 909, 915, 916, 922, 923, 927, 1028, 1029, 1037, 1038, 1040, 1041, 1045, 1053, 1055, 1091, 1093, 1095, 1111, 1113, 1117, 1118, 1732, 1736, 1738, 1754, 1756, 1762, 1774, 1777, 1779, 1798, 1800, 1808, 1812, 1824, 1826, 1828, 1830, 1831, 1833, 1834, 1835, 1836, 1837, 1838, 1840, 1842, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1858, 1859, 1860, 1862, 1864, 1866, 1869, 1870, 1871, 1872, 1875, 1876, 1878, 1879, 1881, 1882, 1883, 1884, 1885, 1886, 1888, 1889, 1892, 1893, 1894, 1895, 1896, 1897, 1899, 1900, 1901, 1903, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1927, 1928, 1929, 1930, 1932, 1933, 1934, 1935, 1936, 1938, 1940, 1941, 1942, 1943, 1945, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1955, 1958, 1959, 1961, 1962, 1964, 1965, 1967, 1968, 1970, 1971, 1973, 1974, 1975, 1977, 1978, 1980, 1981, 1982, 1983, 1984, 1986, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2001, 2002, 2003, 2004, 2006, 2007, 2008, 2009, 2010, 2011, 2014, 2015, 2257, 2286, 2312, 2378, 2444, 2587, 2764, 2827, 3067], 76: [919, 1838, 1879, 1995, 2002], 85: [1929], 89: [1909], 90: [1940], 98: [1902], 99: [1780], 100: [323], 104: [1998], 111: [1955], 118: [1035], 119: [842, 898, 1830, 1877, 1892, 1949, 1952, 1979, 1980, 1996], 123: [1892], 139: [1755], 142: [1829, 1845, 1860, 1870, 1871, 1930, 1931, 1965, 1970, 1973, 1974, 1980, 1981, 1982, 1986, 1999, 2004], 144: [469], 153: [1879], 154: [1839, 1902, 1941]}

# %%
for pid in mod_control_pids:
    print(pid)
    display(M.iloc[indices[pid]])
from IPython.display import FileLink
FileLink('best_models.md')
# Out:
# 1
#       Unnamed: 0               model decision_rule  use_pseudo_rewards  \
# 1872        1872           reinforce           NaN                True
# 2006        2006  baseline_reinforce           NaN               False
#
#       pr_weight actor  term selector learner strategy_space_type  \
# 1872      False   NaN  True      NaN     NaN                 NaN
# 2006      False   NaN  True      NaN     NaN                 NaN
#
#      stochastic_updating subjective_cost vicarious_learning  \
# 1872                 NaN           False               True
# 2006                 NaN           False               True
#
#      termination_value_known montecarlo_updates  is_null is_gaussian  \
# 1872                    True               True     True         NaN
# 2006                   False              False     True         NaN
#
#      bandit_prior            prior
# 1872          NaN  strategy_weight
# 2006          NaN  strategy_weight
# 2
#       Unnamed: 0                 model         decision_rule  \
# 364          364  hierarchical_learner  adaptive_satisficing
# 478          478  hierarchical_learner  adaptive_satisficing
# 1814        1814                  lvoc                   NaN
# 1892        1892             reinforce                   NaN
# 1907        1907             reinforce                   NaN
# 1939        1939    baseline_reinforce                   NaN
# 1950        1950    baseline_reinforce                   NaN
# 1969        1969    baseline_reinforce                   NaN
#
#       use_pseudo_rewards  pr_weight               actor   term selector  \
# 364                 True      False  baseline_reinforce  False      NaN
# 478                False      False           reinforce   True      NaN
# 1814               False      False                 NaN   True      NaN
# 1892               False      False                 NaN   True      NaN
# 1907               False      False                 NaN   True      NaN
# 1939                True       True                 NaN   True      NaN
# 1950                True       True                 NaN   True      NaN
# 1969                True      False                 NaN   True      NaN
#
#      learner strategy_space_type stochastic_updating subjective_cost  \
# 364      NaN                 NaN                 NaN            True
# 478      NaN                 NaN                 NaN           False
# 1814     NaN                 NaN                 NaN           False
# 1892     NaN                 NaN                 NaN            True
# 1907     NaN                 NaN                 NaN           False
# 1939     NaN                 NaN                 NaN           False
# 1950     NaN                 NaN                 NaN           False
# 1969     NaN                 NaN                 NaN           False
#
#      vicarious_learning termination_value_known montecarlo_updates  is_null  \
# 364               False                   False               True     True
# 478               False                   False              False     True
# 1814               True                   False              False     True
# 1892               True                   False               True     True
# 1907               True                    True              False    False
# 1939               True                    True              False    False
# 1950              False                   False              False     True
# 1969               True                    True               True    False
#
#      is_gaussian bandit_prior            prior
# 364          NaN          NaN  strategy_weight
# 478          NaN          NaN  strategy_weight
# 1814         NaN          NaN  strategy_weight
# 1892         NaN          NaN  strategy_weight
# 1907         NaN          NaN  strategy_weight
# 1939         NaN          NaN  strategy_weight
# 1950         NaN          NaN  strategy_weight
# 1969         NaN          NaN  strategy_weight
# 6
#       Unnamed: 0      model decision_rule  use_pseudo_rewards  pr_weight  \
# 1833        1833  reinforce           NaN                True       True
#
#      actor  term selector learner strategy_space_type stochastic_updating  \
# 1833   NaN  True      NaN     NaN                 NaN                 NaN
#
#      subjective_cost vicarious_learning termination_value_known  \
# 1833            True              False                    True
#
#      montecarlo_updates  is_null is_gaussian bandit_prior            prior
# 1833               True    False         NaN          NaN  strategy_weight
# 9
#       Unnamed: 0                 model decision_rule  use_pseudo_rewards  \
# 1108        1108  hierarchical_learner     threshold               False
#
#       pr_weight               actor  term selector learner  \
# 1108      False  baseline_reinforce  True      NaN     NaN
#
#      strategy_space_type stochastic_updating subjective_cost  \
# 1108                 NaN                 NaN           False
#
#      vicarious_learning termination_value_known montecarlo_updates  is_null  \
# 1108               True                   False               True     True
#
#      is_gaussian bandit_prior            prior
# 1108         NaN          NaN  strategy_weight
# 11
#      Unnamed: 0                 model decision_rule  use_pseudo_rewards  \
# 641         641  hierarchical_learner     threshold                True
#
#      pr_weight      actor  term selector learner strategy_space_type  \
# 641       True  reinforce  True      NaN     NaN                 NaN
#
#     stochastic_updating subjective_cost vicarious_learning  \
# 641                 NaN            True               True
#
#     termination_value_known montecarlo_updates  is_null is_gaussian  \
# 641                    True               True    False         NaN
#
#     bandit_prior            prior
# 641          NaN  strategy_weight
# 14
#    Unnamed: 0                 model         decision_rule  use_pseudo_rewards  \
# 9           9  hierarchical_learner  adaptive_satisficing                True
#
#    pr_weight actor  term selector learner strategy_space_type  \
# 9       True  lvoc  True      NaN     NaN                 NaN
#
#   stochastic_updating subjective_cost vicarious_learning  \
# 9                 NaN            True              False
#
#   termination_value_known montecarlo_updates  is_null is_gaussian  \
# 9                    True               True    False         NaN
#
#   bandit_prior            prior
# 9          NaN  strategy_weight
# 18
#       Unnamed: 0               model decision_rule  use_pseudo_rewards  \
# 1959        1959  baseline_reinforce           NaN                True
#
#       pr_weight actor  term selector learner strategy_space_type  \
# 1959      False   NaN  True      NaN     NaN                 NaN
#
#      stochastic_updating subjective_cost vicarious_learning  \
# 1959                 NaN            True               True
#
#      termination_value_known montecarlo_updates  is_null is_gaussian  \
# 1959                   False              False    False         NaN
#
#      bandit_prior            prior
# 1959          NaN  strategy_weight
# 21
#       Unnamed: 0                 model decision_rule  use_pseudo_rewards  \
# 1059        1059  hierarchical_learner     threshold               False
#
#       pr_weight      actor   term selector learner strategy_space_type  \
# 1059      False  reinforce  False      NaN     NaN                 NaN
#
#      stochastic_updating subjective_cost vicarious_learning  \
# 1059                 NaN            True               True
#
#      termination_value_known montecarlo_updates  is_null is_gaussian  \
# 1059                    True              False    False         NaN
#
#      bandit_prior            prior
# 1059          NaN  strategy_weight
# 24
#       Unnamed: 0      model decision_rule  use_pseudo_rewards  pr_weight  \
# 1873        1873  reinforce           NaN                True      False
#
#      actor  term selector learner strategy_space_type stochastic_updating  \
# 1873   NaN  True      NaN     NaN                 NaN                 NaN
#
#      subjective_cost vicarious_learning termination_value_known  \
# 1873           False               True                    True
#
#      montecarlo_updates  is_null is_gaussian bandit_prior            prior
# 1873               True    False         NaN          NaN  strategy_weight
# 27
#       Unnamed: 0      model decision_rule  use_pseudo_rewards  pr_weight  \
# 1899        1899  reinforce           NaN               False      False
#
#      actor  term selector learner strategy_space_type stochastic_updating  \
# 1899   NaN  True      NaN     NaN                 NaN                 NaN
#
#      subjective_cost vicarious_learning termination_value_known  \
# 1899            True              False                    True
#
#      montecarlo_updates  is_null is_gaussian bandit_prior            prior
# 1899              False    False         NaN          NaN  strategy_weight
# 37
#      Unnamed: 0                 model decision_rule  use_pseudo_rewards  \
# 645         645  hierarchical_learner     threshold                True
#
#      pr_weight      actor  term selector learner strategy_space_type  \
# 645       True  reinforce  True      NaN     NaN                 NaN
#
#     stochastic_updating subjective_cost vicarious_learning  \
# 645                 NaN            True               True
#
#     termination_value_known montecarlo_updates  is_null is_gaussian  \
# 645                   False               True    False         NaN
#
#     bandit_prior            prior
# 645          NaN  strategy_weight
# 38
#       Unnamed: 0               model decision_rule  use_pseudo_rewards  \
# 1997        1997  baseline_reinforce           NaN               False
#
#       pr_weight actor  term selector learner strategy_space_type  \
# 1997      False   NaN  True      NaN     NaN                 NaN
#
#      stochastic_updating subjective_cost vicarious_learning  \
# 1997                 NaN            True              False
#
#      termination_value_known montecarlo_updates  is_null is_gaussian  \
# 1997                   False               True    False         NaN
#
#      bandit_prior            prior
# 1997          NaN  strategy_weight
# 44
#      Unnamed: 0                 model decision_rule  use_pseudo_rewards  \
# 711         711  hierarchical_learner     threshold                True
#
#      pr_weight               actor  term selector learner strategy_space_type  \
# 711       True  baseline_reinforce  True      NaN     NaN                 NaN
#
#     stochastic_updating subjective_cost vicarious_learning  \
# 711                 NaN            True               True
#
#     termination_value_known montecarlo_updates  is_null is_gaussian  \
# 711                   False              False    False         NaN
#
#     bandit_prior            prior
# 711          NaN  strategy_weight
# 50
#       Unnamed: 0               model decision_rule  use_pseudo_rewards  \
# 1893        1893           reinforce           NaN               False
# 2001        2001  baseline_reinforce           NaN               False
#
#       pr_weight actor  term selector learner strategy_space_type  \
# 1893      False   NaN  True      NaN     NaN                 NaN
# 2001      False   NaN  True      NaN     NaN                 NaN
#
#      stochastic_updating subjective_cost vicarious_learning  \
# 1893                 NaN            True               True
# 2001                 NaN           False               True
#
#      termination_value_known montecarlo_updates  is_null is_gaussian  \
# 1893                   False               True    False         NaN
# 2001                    True               True    False         NaN
#
#      bandit_prior            prior
# 1893          NaN  strategy_weight
# 2001          NaN  strategy_weight
# 55
#       Unnamed: 0               model decision_rule  use_pseudo_rewards  \
# 1860        1860           reinforce           NaN                True
# 1954        1954  baseline_reinforce           NaN                True
#
#       pr_weight actor  term selector learner strategy_space_type  \
# 1860      False   NaN  True      NaN     NaN                 NaN
# 1954      False   NaN  True      NaN     NaN                 NaN
#
#      stochastic_updating subjective_cost vicarious_learning  \
# 1860                 NaN            True               True
# 1954                 NaN            True               True
#
#      termination_value_known montecarlo_updates  is_null is_gaussian  \
# 1860                   False               True     True         NaN
# 1954                    True              False     True         NaN
#
#      bandit_prior            prior
# 1860          NaN  strategy_weight
# 1954          NaN  strategy_weight
# 56
#      Unnamed: 0                 model decision_rule  use_pseudo_rewards  \
# 901         901  hierarchical_learner     threshold                True
#
#      pr_weight               actor  term selector learner strategy_space_type  \
# 901      False  baseline_reinforce  True      NaN     NaN                 NaN
#
#     stochastic_updating subjective_cost vicarious_learning  \
# 901                 NaN            True               True
#
#     termination_value_known montecarlo_updates  is_null is_gaussian  \
# 901                   False               True    False         NaN
#
#     bandit_prior            prior
# 901          NaN  strategy_weight
# 58
#       Unnamed: 0               model decision_rule  use_pseudo_rewards  \
# 1948        1948  baseline_reinforce           NaN                True
#
#       pr_weight actor  term selector learner strategy_space_type  \
# 1948       True   NaN  True      NaN     NaN                 NaN
#
#      stochastic_updating subjective_cost vicarious_learning  \
# 1948                 NaN           False              False
#
#      termination_value_known montecarlo_updates  is_null is_gaussian  \
# 1948                   False               True     True         NaN
#
#      bandit_prior            prior
# 1948          NaN  strategy_weight
# 66
#       Unnamed: 0                 model         decision_rule  \
# 4              4  hierarchical_learner  adaptive_satisficing
# 11            11  hierarchical_learner  adaptive_satisficing
# 14            14  hierarchical_learner  adaptive_satisficing
# 64            64  hierarchical_learner  adaptive_satisficing
# 75            75  hierarchical_learner  adaptive_satisficing
# ...          ...                   ...                   ...
# 2444        2444                  sdss                   NaN
# 2587        2587                  sdss                   NaN
# 2764        2764                  sdss                   NaN
# 2827        2827                  sdss                   NaN
# 3067        3067                  sdss                   NaN
#
#       use_pseudo_rewards  pr_weight      actor  term selector  \
# 4                   True       True       lvoc  True      NaN
# 11                  True       True       lvoc  True      NaN
# 14                  True       True       lvoc  True      NaN
# 64                  True       True  reinforce  True      NaN
# 75                  True       True  reinforce  True      NaN
# ...                  ...        ...        ...   ...      ...
# 2444                True       True        NaN  True     rssl
# 2587                True      False        NaN  True     rssl
# 2764                True      False        NaN  True     rssl
# 2827                True      False        NaN  True     rssl
# 3067               False      False        NaN  True     rssl
#
#                  learner strategy_space_type stochastic_updating  \
# 4                    NaN                 NaN                 NaN
# 11                   NaN                 NaN                 NaN
# 14                   NaN                 NaN                 NaN
# 64                   NaN                 NaN                 NaN
# 75                   NaN                 NaN                 NaN
# ...                  ...                 ...                 ...
# 2444  baseline_reinforce                 NaN               False
# 2587           reinforce                 NaN                True
# 2764  baseline_reinforce                 NaN                True
# 2827  baseline_reinforce                 NaN               False
# 3067           reinforce                 NaN               False
#
#      subjective_cost vicarious_learning termination_value_known  \
# 4               True               True                   False
# 11              True              False                    True
# 14              True              False                   False
# 64              True               True                    True
# 75              True              False                    True
# ...              ...                ...                     ...
# 2444           False              False                   False
# 2587            True               True                   False
# 2764           False              False                   False
# 2827           False              False                   False
# 3067           False               True                   False
#
#      montecarlo_updates  is_null is_gaussian bandit_prior            prior
# 4                  True     True         NaN          NaN  strategy_weight
# 11                False    False         NaN          NaN  strategy_weight
# 14                False     True         NaN          NaN  strategy_weight
# 64                 True     True         NaN          NaN  strategy_weight
# 75                False    False         NaN          NaN  strategy_weight
# ...                 ...      ...         ...          ...              ...
# 2444              False     True        True         True  strategy_weight
# 2587               True    False       False         True  strategy_weight
# 2764              False     True        True         True  strategy_weight
# 2827               True    False       False         True  strategy_weight
# 3067               True    False       False         True  strategy_weight
#
# [252 rows x 19 columns]
# 76
#       Unnamed: 0                 model decision_rule  use_pseudo_rewards  \
# 919          919  hierarchical_learner     threshold                True
# 1838        1838             reinforce           NaN                True
# 1879        1879             reinforce           NaN                True
# 1995        1995    baseline_reinforce           NaN               False
# 2002        2002    baseline_reinforce           NaN               False
#
#       pr_weight               actor  term selector learner  \
# 919       False  baseline_reinforce  True      NaN     NaN
# 1838       True                 NaN  True      NaN     NaN
# 1879      False                 NaN  True      NaN     NaN
# 1995      False                 NaN  True      NaN     NaN
# 2002      False                 NaN  True      NaN     NaN
#
#      strategy_space_type stochastic_updating subjective_cost  \
# 919                  NaN                 NaN           False
# 1838                 NaN                 NaN            True
# 1879                 NaN                 NaN           False
# 1995                 NaN                 NaN            True
# 2002                 NaN                 NaN           False
#
#      vicarious_learning termination_value_known montecarlo_updates  is_null  \
# 919                True                   False              False    False
# 1838              False                   False              False     True
# 1879               True                   False              False    False
# 1995              False                    True              False    False
# 2002               True                    True              False     True
#
#      is_gaussian bandit_prior            prior
# 919          NaN          NaN  strategy_weight
# 1838         NaN          NaN  strategy_weight
# 1879         NaN          NaN  strategy_weight
# 1995         NaN          NaN  strategy_weight
# 2002         NaN          NaN  strategy_weight
# 85
#       Unnamed: 0               model decision_rule  use_pseudo_rewards  \
# 1929        1929  baseline_reinforce           NaN                True
#
#       pr_weight actor  term selector learner strategy_space_type  \
# 1929       True   NaN  True      NaN     NaN                 NaN
#
#      stochastic_updating subjective_cost vicarious_learning  \
# 1929                 NaN            True              False
#
#      termination_value_known montecarlo_updates  is_null is_gaussian  \
# 1929                    True               True    False         NaN
#
#      bandit_prior            prior
# 1929          NaN  strategy_weight
# 89
#       Unnamed: 0      model decision_rule  use_pseudo_rewards  pr_weight  \
# 1909        1909  reinforce           NaN               False      False
#
#      actor  term selector learner strategy_space_type stochastic_updating  \
# 1909   NaN  True      NaN     NaN                 NaN                 NaN
#
#      subjective_cost vicarious_learning termination_value_known  \
# 1909           False               True                   False
#
#      montecarlo_updates  is_null is_gaussian bandit_prior            prior
# 1909               True    False         NaN          NaN  strategy_weight
# 90
#       Unnamed: 0               model decision_rule  use_pseudo_rewards  \
# 1940        1940  baseline_reinforce           NaN                True
#
#       pr_weight actor  term selector learner strategy_space_type  \
# 1940       True   NaN  True      NaN     NaN                 NaN
#
#      stochastic_updating subjective_cost vicarious_learning  \
# 1940                 NaN           False               True
#
#      termination_value_known montecarlo_updates  is_null is_gaussian  \
# 1940                   False               True     True         NaN
#
#      bandit_prior            prior
# 1940          NaN  strategy_weight
# 98
#       Unnamed: 0      model decision_rule  use_pseudo_rewards  pr_weight  \
# 1902        1902  reinforce           NaN               False      False
#
#      actor  term selector learner strategy_space_type stochastic_updating  \
# 1902   NaN  True      NaN     NaN                 NaN                 NaN
#
#      subjective_cost vicarious_learning termination_value_known  \
# 1902            True              False                   False
#
#      montecarlo_updates  is_null is_gaussian bandit_prior            prior
# 1902              False     True         NaN          NaN  strategy_weight
# 99
#       Unnamed: 0 model decision_rule  use_pseudo_rewards  pr_weight actor  \
# 1780        1780  lvoc           NaN                True      False   NaN
#
#       term selector learner strategy_space_type stochastic_updating  \
# 1780  True      NaN     NaN                 NaN                 NaN
#
#      subjective_cost vicarious_learning termination_value_known  \
# 1780           False               True                   False
#
#      montecarlo_updates  is_null is_gaussian bandit_prior            prior
# 1780               True     True         NaN          NaN  strategy_weight
# 100
#      Unnamed: 0                 model         decision_rule  \
# 323         323  hierarchical_learner  adaptive_satisficing
#
#      use_pseudo_rewards  pr_weight               actor  term selector learner  \
# 323                True      False  baseline_reinforce  True      NaN     NaN
#
#     strategy_space_type stochastic_updating subjective_cost  \
# 323                 NaN                 NaN            True
#
#     vicarious_learning termination_value_known montecarlo_updates  is_null  \
# 323               True                    True              False    False
#
#     is_gaussian bandit_prior            prior
# 323         NaN          NaN  strategy_weight
# 104
#       Unnamed: 0               model decision_rule  use_pseudo_rewards  \
# 1998        1998  baseline_reinforce           NaN               False
#
#       pr_weight actor  term selector learner strategy_space_type  \
# 1998      False   NaN  True      NaN     NaN                 NaN
#
#      stochastic_updating subjective_cost vicarious_learning  \
# 1998                 NaN            True              False
#
#      termination_value_known montecarlo_updates  is_null is_gaussian  \
# 1998                   False              False     True         NaN
#
#      bandit_prior            prior
# 1998          NaN  strategy_weight
# 111
#       Unnamed: 0               model decision_rule  use_pseudo_rewards  \
# 1955        1955  baseline_reinforce           NaN                True
#
#       pr_weight actor  term selector learner strategy_space_type  \
# 1955      False   NaN  True      NaN     NaN                 NaN
#
#      stochastic_updating subjective_cost vicarious_learning  \
# 1955                 NaN            True               True
#
#      termination_value_known montecarlo_updates  is_null is_gaussian  \
# 1955                    True              False    False         NaN
#
#      bandit_prior            prior
# 1955          NaN  strategy_weight
# 118
#       Unnamed: 0                 model decision_rule  use_pseudo_rewards  \
# 1035        1035  hierarchical_learner     threshold               False
#
#       pr_weight      actor  term selector learner strategy_space_type  \
# 1035      False  reinforce  True      NaN     NaN                 NaN
#
#      stochastic_updating subjective_cost vicarious_learning  \
# 1035                 NaN            True              False
#
#      termination_value_known montecarlo_updates  is_null is_gaussian  \
# 1035                    True              False    False         NaN
#
#      bandit_prior            prior
# 1035          NaN  strategy_weight
# 119
#       Unnamed: 0                 model decision_rule  use_pseudo_rewards  \
# 842          842  hierarchical_learner     threshold                True
# 898          898  hierarchical_learner     threshold                True
# 1830        1830             reinforce           NaN                True
# 1877        1877             reinforce           NaN                True
# 1892        1892             reinforce           NaN               False
# 1949        1949    baseline_reinforce           NaN                True
# 1952        1952    baseline_reinforce           NaN                True
# 1979        1979    baseline_reinforce           NaN                True
# 1980        1980    baseline_reinforce           NaN                True
# 1996        1996    baseline_reinforce           NaN               False
#
#       pr_weight               actor  term selector learner  \
# 842       False           reinforce  True      NaN     NaN
# 898       False  baseline_reinforce  True      NaN     NaN
# 1830       True                 NaN  True      NaN     NaN
# 1877      False                 NaN  True      NaN     NaN
# 1892      False                 NaN  True      NaN     NaN
# 1949       True                 NaN  True      NaN     NaN
# 1952      False                 NaN  True      NaN     NaN
# 1979      False                 NaN  True      NaN     NaN
# 1980      False                 NaN  True      NaN     NaN
# 1996      False                 NaN  True      NaN     NaN
#
#      strategy_space_type stochastic_updating subjective_cost  \
# 842                  NaN                 NaN            True
# 898                  NaN                 NaN            True
# 1830                 NaN                 NaN            True
# 1877                 NaN                 NaN           False
# 1892                 NaN                 NaN            True
# 1949                 NaN                 NaN           False
# 1952                 NaN                 NaN            True
# 1979                 NaN                 NaN           False
# 1980                 NaN                 NaN           False
# 1996                 NaN                 NaN            True
#
#      vicarious_learning termination_value_known montecarlo_updates  is_null  \
# 842               False                    True              False     True
# 898                True                    True              False     True
# 1830               True                   False              False     True
# 1877               True                   False               True    False
# 1892               True                   False               True     True
# 1949              False                   False               True    False
# 1952               True                    True               True     True
# 1979              False                    True              False    False
# 1980              False                   False               True     True
# 1996              False                   False               True     True
#
#      is_gaussian bandit_prior            prior
# 842          NaN          NaN  strategy_weight
# 898          NaN          NaN  strategy_weight
# 1830         NaN          NaN  strategy_weight
# 1877         NaN          NaN  strategy_weight
# 1892         NaN          NaN  strategy_weight
# 1949         NaN          NaN  strategy_weight
# 1952         NaN          NaN  strategy_weight
# 1979         NaN          NaN  strategy_weight
# 1980         NaN          NaN  strategy_weight
# 1996         NaN          NaN  strategy_weight
# 123
#       Unnamed: 0      model decision_rule  use_pseudo_rewards  pr_weight  \
# 1892        1892  reinforce           NaN               False      False
#
#      actor  term selector learner strategy_space_type stochastic_updating  \
# 1892   NaN  True      NaN     NaN                 NaN                 NaN
#
#      subjective_cost vicarious_learning termination_value_known  \
# 1892            True               True                   False
#
#      montecarlo_updates  is_null is_gaussian bandit_prior            prior
# 1892               True     True         NaN          NaN  strategy_weight
# 139
#       Unnamed: 0 model decision_rule  use_pseudo_rewards  pr_weight actor  \
# 1755        1755  lvoc           NaN                True       True   NaN
#
#       term selector learner strategy_space_type stochastic_updating  \
# 1755  True      NaN     NaN                 NaN                 NaN
#
#      subjective_cost vicarious_learning termination_value_known  \
# 1755           False              False                    True
#
#      montecarlo_updates  is_null is_gaussian bandit_prior            prior
# 1755              False    False         NaN          NaN  strategy_weight
# 142
#       Unnamed: 0               model decision_rule  use_pseudo_rewards  \
# 1829        1829           reinforce           NaN                True
# 1845        1845           reinforce           NaN                True
# 1860        1860           reinforce           NaN                True
# 1870        1870           reinforce           NaN                True
# 1871        1871           reinforce           NaN                True
# 1930        1930  baseline_reinforce           NaN                True
# 1931        1931  baseline_reinforce           NaN                True
# 1965        1965  baseline_reinforce           NaN                True
# 1970        1970  baseline_reinforce           NaN                True
# 1973        1973  baseline_reinforce           NaN                True
# 1974        1974  baseline_reinforce           NaN                True
# 1980        1980  baseline_reinforce           NaN                True
# 1981        1981  baseline_reinforce           NaN                True
# 1982        1982  baseline_reinforce           NaN                True
# 1986        1986  baseline_reinforce           NaN               False
# 1999        1999  baseline_reinforce           NaN               False
# 2004        2004  baseline_reinforce           NaN               False
#
#       pr_weight actor  term selector learner strategy_space_type  \
# 1829       True   NaN  True      NaN     NaN                 NaN
# 1845       True   NaN  True      NaN     NaN                 NaN
# 1860      False   NaN  True      NaN     NaN                 NaN
# 1870      False   NaN  True      NaN     NaN                 NaN
# 1871      False   NaN  True      NaN     NaN                 NaN
# 1930       True   NaN  True      NaN     NaN                 NaN
# 1931       True   NaN  True      NaN     NaN                 NaN
# 1965      False   NaN  True      NaN     NaN                 NaN
# 1970      False   NaN  True      NaN     NaN                 NaN
# 1973      False   NaN  True      NaN     NaN                 NaN
# 1974      False   NaN  True      NaN     NaN                 NaN
# 1980      False   NaN  True      NaN     NaN                 NaN
# 1981      False   NaN  True      NaN     NaN                 NaN
# 1982      False   NaN  True      NaN     NaN                 NaN
# 1986      False   NaN  True      NaN     NaN                 NaN
# 1999      False   NaN  True      NaN     NaN                 NaN
# 2004      False   NaN  True      NaN     NaN                 NaN
#
#      stochastic_updating subjective_cost vicarious_learning  \
# 1829                 NaN            True               True
# 1845                 NaN           False               True
# 1860                 NaN            True               True
# 1870                 NaN            True              False
# 1871                 NaN            True              False
# 1930                 NaN            True              False
# 1931                 NaN            True              False
# 1965                 NaN            True              False
# 1970                 NaN           False               True
# 1973                 NaN           False               True
# 1974                 NaN           False               True
# 1980                 NaN           False              False
# 1981                 NaN           False              False
# 1982                 NaN           False              False
# 1986                 NaN            True               True
# 1999                 NaN            True              False
# 2004                 NaN           False               True
#
#      termination_value_known montecarlo_updates  is_null is_gaussian  \
# 1829                   False               True    False         NaN
# 1845                   False               True    False         NaN
# 1860                   False               True     True         NaN
# 1870                   False              False     True         NaN
# 1871                   False              False    False         NaN
# 1930                    True              False     True         NaN
# 1931                    True              False    False         NaN
# 1965                   False               True    False         NaN
# 1970                    True              False     True         NaN
# 1973                   False               True    False         NaN
# 1974                   False              False     True         NaN
# 1980                   False               True     True         NaN
# 1981                   False               True    False         NaN
# 1982                   False              False     True         NaN
# 1986                    True              False     True         NaN
# 1999                   False              False    False         NaN
# 2004                   False               True     True         NaN
#
#      bandit_prior            prior
# 1829          NaN  strategy_weight
# 1845          NaN  strategy_weight
# 1860          NaN  strategy_weight
# 1870          NaN  strategy_weight
# 1871          NaN  strategy_weight
# 1930          NaN  strategy_weight
# 1931          NaN  strategy_weight
# 1965          NaN  strategy_weight
# 1970          NaN  strategy_weight
# 1973          NaN  strategy_weight
# 1974          NaN  strategy_weight
# 1980          NaN  strategy_weight
# 1981          NaN  strategy_weight
# 1982          NaN  strategy_weight
# 1986          NaN  strategy_weight
# 1999          NaN  strategy_weight
# 2004          NaN  strategy_weight
# 144
#      Unnamed: 0                 model         decision_rule  \
# 469         469  hierarchical_learner  adaptive_satisficing
#
#      use_pseudo_rewards  pr_weight      actor  term selector learner  \
# 469               False      False  reinforce  True      NaN     NaN
#
#     strategy_space_type stochastic_updating subjective_cost  \
# 469                 NaN                 NaN           False
#
#     vicarious_learning termination_value_known montecarlo_updates  is_null  \
# 469               True                   False               True    False
#
#     is_gaussian bandit_prior            prior
# 469         NaN          NaN  strategy_weight
# 153
#       Unnamed: 0      model decision_rule  use_pseudo_rewards  pr_weight  \
# 1879        1879  reinforce           NaN                True      False
#
#      actor  term selector learner strategy_space_type stochastic_updating  \
# 1879   NaN  True      NaN     NaN                 NaN                 NaN
#
#      subjective_cost vicarious_learning termination_value_known  \
# 1879           False               True                   False
#
#      montecarlo_updates  is_null is_gaussian bandit_prior            prior
# 1879              False    False         NaN          NaN  strategy_weight
# 154
#       Unnamed: 0               model decision_rule  use_pseudo_rewards  \
# 1839        1839           reinforce           NaN                True
# 1902        1902           reinforce           NaN               False
# 1941        1941  baseline_reinforce           NaN                True
#
#       pr_weight actor  term selector learner strategy_space_type  \
# 1839       True   NaN  True      NaN     NaN                 NaN
# 1902      False   NaN  True      NaN     NaN                 NaN
# 1941       True   NaN  True      NaN     NaN                 NaN
#
#      stochastic_updating subjective_cost vicarious_learning  \
# 1839                 NaN            True              False
# 1902                 NaN            True              False
# 1941                 NaN           False               True
#
#      termination_value_known montecarlo_updates  is_null is_gaussian  \
# 1839                   False              False    False         NaN
# 1902                   False              False     True         NaN
# 1941                   False               True    False         NaN
#
#      bandit_prior            prior
# 1839          NaN  strategy_weight
# 1902          NaN  strategy_weight
# 1941          NaN  strategy_weight
# /Users/yjain/modeling_mcl/python/best_models.md

# %%
import numpy as np
models = [0, 1, 64, 65, 576, 577, 640, 641, 1728, 1729, 1824, 1825]
# control_pids = [1, 2, 6, 9, 11, 14, 18, 21, 24, 27, 37, 38, 44, 50, 55, 56, 58, 66, 76, 79, 85, 89, 90, 98, 99,
#                 100, 104, 111, 113, 118, 119, 123, 126, 129, 139, 142, 144, 153, 154]
obj = "mer_performance_error"
for model in models:
    p_rs = []
    a_rs = []
    for pid in range(120):
        try:
            reward_data = pickle_load(f"results/T1.1_run_results/{pid}_{obj}_{model}.pkl")
            p_r = reward_data[reward_data.algo == 'participant'].y.tolist()
            a_r = reward_data[reward_data.algo == 'algo'].y.tolist()
            p_rs.append(p_r)
            a_rs.append(a_r)
        except Exception as e:
            print(e)
            continue
    plt.figure()
    plt.plot(np.mean(a_rs, axis=0), label='algo')
    plt.plot(np.mean(p_rs, axis=0), label='participant')
    plt.title(model)
    plt.legend()

# %%
import pandas as pd
df = pd.read_csv("rl_models.csv")
df['r'] = rewards

# %%
print(df)
# Out:
#       Unnamed: 0                 model         decision_rule  \
# 0              0  hierarchical_learner  adaptive_satisficing
# 1              1  hierarchical_learner  adaptive_satisficing
# 2              2  hierarchical_learner  adaptive_satisficing
# 3              3  hierarchical_learner  adaptive_satisficing
# 4              4  hierarchical_learner  adaptive_satisficing
# ...          ...                   ...                   ...
# 3211        3211                  sdss                   NaN
# 3212        3212                  sdss                   NaN
# 3213        3213                  sdss                   NaN
# 3214        3214                  sdss                   NaN
# 3215        3215                  sdss                   NaN
#
#       use_pseudo_rewards  pr_weight actor  term selector             learner  \
# 0                   True       True  lvoc  True      NaN                 NaN
# 1                   True       True  lvoc  True      NaN                 NaN
# 2                   True       True  lvoc  True      NaN                 NaN
# 3                   True       True  lvoc  True      NaN                 NaN
# 4                   True       True  lvoc  True      NaN                 NaN
# ...                  ...        ...   ...   ...      ...                 ...
# 3211               False      False   NaN  True     rssl  baseline_reinforce
# 3212               False      False   NaN  True     rssl  baseline_reinforce
# 3213               False      False   NaN  True     rssl  baseline_reinforce
# 3214               False      False   NaN  True     rssl  baseline_reinforce
# 3215               False      False   NaN  True     rssl  baseline_reinforce
#
#      strategy_space_type stochastic_updating subjective_cost  \
# 0                    NaN                 NaN            True
# 1                    NaN                 NaN            True
# 2                    NaN                 NaN            True
# 3                    NaN                 NaN            True
# 4                    NaN                 NaN            True
# ...                  ...                 ...             ...
# 3211                 NaN               False           False
# 3212                 NaN               False           False
# 3213                 NaN               False           False
# 3214                 NaN               False           False
# 3215                 NaN               False           False
#
#      vicarious_learning termination_value_known montecarlo_updates  is_null  \
# 0                  True                    True               True     True
# 1                  True                    True               True    False
# 2                  True                    True              False     True
# 3                  True                    True              False    False
# 4                  True                   False               True     True
# ...                 ...                     ...                ...      ...
# 3211              False                   False               True    False
# 3212              False                   False              False     True
# 3213              False                   False              False     True
# 3214              False                   False              False    False
# 3215              False                   False              False    False
#
#      is_gaussian bandit_prior            prior      r
# 0            NaN          NaN  strategy_weight  35.17
# 1            NaN          NaN  strategy_weight  34.17
# 2            NaN          NaN  strategy_weight  29.09
# 3            NaN          NaN  strategy_weight  35.68
# 4            NaN          NaN  strategy_weight  39.35
# ...          ...          ...              ...    ...
# 3211       False         True  strategy_weight  34.21
# 3212        True         True  strategy_weight  33.44
# 3213       False         True  strategy_weight  37.81
# 3214        True         True  strategy_weight  35.11
# 3215       False         True  strategy_weight  35.29
#
# [3216 rows x 20 columns]

# %%
df = df[~(df.decision_rule == "confidence_bound")]

# %%
df = df[df.r <= 35]

# %%
df.sort_values(['r'], ascending=False)
# Out:
#       Unnamed: 0                 model         decision_rule  \
# 2589        2589                  sdss                   NaN
# 2082        2082                  sdss                   NaN
# 2476        2476                  sdss                   NaN
# 2089        2089                  sdss                   NaN
# 153          153  hierarchical_learner  adaptive_satisficing
# 2227        2227                  sdss                   NaN
# 2667        2667                  sdss                   NaN
# 192          192  hierarchical_learner  adaptive_satisficing
# 2836        2836                  sdss                   NaN
# 199          199  hierarchical_learner  adaptive_satisficing
# 2668        2668                  sdss                   NaN
# 2059        2059                  rssl                   NaN
# 2652        2652                  sdss                   NaN
# 1997        1997    baseline_reinforce                   NaN
# 104          104  hierarchical_learner  adaptive_satisficing
# 739          739  hierarchical_learner             threshold
# 2429        2429                  sdss                   NaN
# 2940        2940                  sdss                   NaN
# 2778        2778                  sdss                   NaN
# 2104        2104                  sdss                   NaN
# 2418        2418                  sdss                   NaN
# 2948        2948                  sdss                   NaN
# 1739        1739                  lvoc                   NaN
# 1928        1928    baseline_reinforce                   NaN
# 2184        2184                  sdss                   NaN
# 3198        3198                  sdss                   NaN
# 2330        2330                  sdss                   NaN
# 2121        2121                  sdss                   NaN
# 3114        3114                  sdss                   NaN
# 1989        1989    baseline_reinforce                   NaN
# 2712        2712                  sdss                   NaN
# 1125        1125  hierarchical_learner             threshold
# 3130        3130                  sdss                   NaN
# 1742        1742                  lvoc                   NaN
# 2707        2707                  sdss                   NaN
# 2108        2108                  sdss                   NaN
# 419          419  hierarchical_learner  adaptive_satisficing
# 1042        1042  hierarchical_learner             threshold
# 2568        2568                  sdss                   NaN
# 2706        2706                  sdss                   NaN
# 2491        2491                  sdss                   NaN
# 366          366  hierarchical_learner  adaptive_satisficing
# 2073        2073                  sdss                   NaN
# 1964        1964    baseline_reinforce                   NaN
# 140          140  hierarchical_learner  adaptive_satisficing
# 225          225  hierarchical_learner  adaptive_satisficing
# 970          970  hierarchical_learner             threshold
# 2235        2235                  sdss                   NaN
# 2148        2148                  sdss                   NaN
# 2774        2774                  sdss                   NaN
# 2696        2696                  sdss                   NaN
# 2393        2393                  sdss                   NaN
# 43            43  hierarchical_learner  adaptive_satisficing
# 426          426  hierarchical_learner  adaptive_satisficing
# 2655        2655                  sdss                   NaN
# 2338        2338                  sdss                   NaN
# 2201        2201                  sdss                   NaN
# 2602        2602                  sdss                   NaN
# 2936        2936                  sdss                   NaN
# 2454        2454                  sdss                   NaN
# 3119        3119                  sdss                   NaN
# 3040        3040                  sdss                   NaN
# 2641        2641                  sdss                   NaN
# 2558        2558                  sdss                   NaN
# 683          683  hierarchical_learner             threshold
# 129          129  hierarchical_learner  adaptive_satisficing
# 1780        1780                  lvoc                   NaN
# 2731        2731                  sdss                   NaN
# 1730        1730                  lvoc                   NaN
# 3084        3084                  sdss                   NaN
# 2228        2228                  sdss                   NaN
# 380          380  hierarchical_learner  adaptive_satisficing
# 2625        2625                  sdss                   NaN
# 1999        1999    baseline_reinforce                   NaN
# 3063        3063                  sdss                   NaN
# 2737        2737                  sdss                   NaN
# 2162        2162                  sdss                   NaN
# 2100        2100                  sdss                   NaN
# 2078        2078                  sdss                   NaN
# 2807        2807                  sdss                   NaN
# 3163        3163                  sdss                   NaN
# 960          960  hierarchical_learner             threshold
# 2279        2279                  sdss                   NaN
# 767          767  hierarchical_learner             threshold
# 281          281  hierarchical_learner  adaptive_satisficing
# 305          305  hierarchical_learner  adaptive_satisficing
# 2085        2085                  sdss                   NaN
# 128          128  hierarchical_learner  adaptive_satisficing
# 936          936  hierarchical_learner             threshold
# 2434        2434                  sdss                   NaN
# 2860        2860                  sdss                   NaN
# 2115        2115                  sdss                   NaN
# 565          565  hierarchical_learner  adaptive_satisficing
# 2479        2479                  sdss                   NaN
# 201          201  hierarchical_learner  adaptive_satisficing
# 2779        2779                  sdss                   NaN
# 2666        2666                  sdss                   NaN
# 978          978  hierarchical_learner             threshold
# 2715        2715                  sdss                   NaN
# 2870        2870                  sdss                   NaN
# 2456        2456                  sdss                   NaN
# 9              9  hierarchical_learner  adaptive_satisficing
# 2465        2465                  sdss                   NaN
# 555          555  hierarchical_learner  adaptive_satisficing
# 1885        1885             reinforce                   NaN
# 236          236  hierarchical_learner  adaptive_satisficing
# 2814        2814                  sdss                   NaN
# 729          729  hierarchical_learner             threshold
# 2335        2335                  sdss                   NaN
# 2425        2425                  sdss                   NaN
# 2211        2211                  sdss                   NaN
# 1065        1065  hierarchical_learner             threshold
# 2989        2989                  sdss                   NaN
# 1965        1965    baseline_reinforce                   NaN
# 3088        3088                  sdss                   NaN
# 2091        2091                  sdss                   NaN
# 1771        1771                  lvoc                   NaN
# 340          340  hierarchical_learner  adaptive_satisficing
# 2349        2349                  sdss                   NaN
# 2431        2431                  sdss                   NaN
# 798          798  hierarchical_learner             threshold
# 2405        2405                  sdss                   NaN
# 3096        3096                  sdss                   NaN
# 2672        2672                  sdss                   NaN
# 2937        2937                  sdss                   NaN
# 2488        2488                  sdss                   NaN
# 2505        2505                  sdss                   NaN
# 2921        2921                  sdss                   NaN
# 2735        2735                  sdss                   NaN
# 2390        2390                  sdss                   NaN
# 2190        2190                  sdss                   NaN
# 2440        2440                  sdss                   NaN
# 2511        2511                  sdss                   NaN
# 2382        2382                  sdss                   NaN
# 2570        2570                  sdss                   NaN
# 193          193  hierarchical_learner  adaptive_satisficing
# 1823        1823                  lvoc                   NaN
# 3022        3022                  sdss                   NaN
# 2251        2251                  sdss                   NaN
# 3046        3046                  sdss                   NaN
# 777          777  hierarchical_learner             threshold
# 2049        2049                  rssl                   NaN
# 2939        2939                  sdss                   NaN
# 369          369  hierarchical_learner  adaptive_satisficing
# 2584        2584                  sdss                   NaN
# 370          370  hierarchical_learner  adaptive_satisficing
# 2512        2512                  sdss                   NaN
# 1772        1772                  lvoc                   NaN
# 882          882  hierarchical_learner             threshold
# 1955        1955    baseline_reinforce                   NaN
# 2573        2573                  sdss                   NaN
# 2902        2902                  sdss                   NaN
# 2544        2544                  sdss                   NaN
# 2441        2441                  sdss                   NaN
# 957          957  hierarchical_learner             threshold
# 1754        1754                  lvoc                   NaN
# 869          869  hierarchical_learner             threshold
# 449          449  hierarchical_learner  adaptive_satisficing
# 1063        1063  hierarchical_learner             threshold
# 30            30  hierarchical_learner  adaptive_satisficing
# 2733        2733                  sdss                   NaN
# 2170        2170                  sdss                   NaN
# 3070        3070                  sdss                   NaN
# 3051        3051                  sdss                   NaN
# 3065        3065                  sdss                   NaN
# 1756        1756                  lvoc                   NaN
# 3132        3132                  sdss                   NaN
# 2453        2453                  sdss                   NaN
# 2124        2124                  sdss                   NaN
# 2820        2820                  sdss                   NaN
# 3077        3077                  sdss                   NaN
# 1781        1781                  lvoc                   NaN
# 1819        1819                  lvoc                   NaN
# 2664        2664                  sdss                   NaN
# 2285        2285                  sdss                   NaN
# 775          775  hierarchical_learner             threshold
# 989          989  hierarchical_learner             threshold
# 459          459  hierarchical_learner  adaptive_satisficing
# 3045        3045                  sdss                   NaN
# 550          550  hierarchical_learner  adaptive_satisficing
# 2272        2272                  sdss                   NaN
# 3211        3211                  sdss                   NaN
# 72            72  hierarchical_learner  adaptive_satisficing
# 2965        2965                  sdss                   NaN
# 719          719  hierarchical_learner             threshold
# 2255        2255                  sdss                   NaN
# 2665        2665                  sdss                   NaN
# 1803        1803                  lvoc                   NaN
# 3133        3133                  sdss                   NaN
# 190          190  hierarchical_learner  adaptive_satisficing
# 2296        2296                  sdss                   NaN
# 1              1  hierarchical_learner  adaptive_satisficing
# 2751        2751                  sdss                   NaN
# 2894        2894                  sdss                   NaN
# 1118        1118  hierarchical_learner             threshold
# 2539        2539                  sdss                   NaN
# 596          596  hierarchical_learner             threshold
# 2301        2301                  sdss                   NaN
# 2234        2234                  sdss                   NaN
# 1782        1782                  lvoc                   NaN
# 2781        2781                  sdss                   NaN
# 2793        2793                  sdss                   NaN
# 911          911  hierarchical_learner             threshold
# 2701        2701                  sdss                   NaN
# 961          961  hierarchical_learner             threshold
# 751          751  hierarchical_learner             threshold
# 2934        2934                  sdss                   NaN
# 3015        3015                  sdss                   NaN
# 2549        2549                  sdss                   NaN
# 2487        2487                  sdss                   NaN
# 2953        2953                  sdss                   NaN
# 1849        1849             reinforce                   NaN
# 157          157  hierarchical_learner  adaptive_satisficing
# 2981        2981                  sdss                   NaN
# 2178        2178                  sdss                   NaN
# 2109        2109                  sdss                   NaN
# 2093        2093                  sdss                   NaN
# 2766        2766                  sdss                   NaN
# 2473        2473                  sdss                   NaN
# 386          386  hierarchical_learner  adaptive_satisficing
# 3038        3038                  sdss                   NaN
# 2606        2606                  sdss                   NaN
# 2379        2379                  sdss                   NaN
# 2305        2305                  sdss                   NaN
# 363          363  hierarchical_learner  adaptive_satisficing
# 1741        1741                  lvoc                   NaN
# 2888        2888                  sdss                   NaN
# 2748        2748                  sdss                   NaN
# 2824        2824                  sdss                   NaN
# 2658        2658                  sdss                   NaN
# 2588        2588                  sdss                   NaN
# 21            21  hierarchical_learner  adaptive_satisficing
# 2027        2027                  rssl                   NaN
# 1841        1841             reinforce                   NaN
# 3099        3099                  sdss                   NaN
# 1840        1840             reinforce                   NaN
# 2876        2876                  sdss                   NaN
# 2575        2575                  sdss                   NaN
# 2723        2723                  sdss                   NaN
# 2135        2135                  sdss                   NaN
# 3168        3168                  sdss                   NaN
# 2728        2728                  sdss                   NaN
# 2253        2253                  sdss                   NaN
# 2872        2872                  sdss                   NaN
# 927          927  hierarchical_learner             threshold
# 2410        2410                  sdss                   NaN
# 2088        2088                  sdss                   NaN
# 2893        2893                  sdss                   NaN
# 2329        2329                  sdss                   NaN
# 55            55  hierarchical_learner  adaptive_satisficing
# 874          874  hierarchical_learner             threshold
# 3209        3209                  sdss                   NaN
# 2408        2408                  sdss                   NaN
# 972          972  hierarchical_learner             threshold
# 3117        3117                  sdss                   NaN
# 2968        2968                  sdss                   NaN
# 2074        2074                  sdss                   NaN
# 2957        2957                  sdss                   NaN
# 3135        3135                  sdss                   NaN
# 2430        2430                  sdss                   NaN
# 2532        2532                  sdss                   NaN
# 2254        2254                  sdss                   NaN
# 2477        2477                  sdss                   NaN
# 2452        2452                  sdss                   NaN
# 1908        1908             reinforce                   NaN
# 67            67  hierarchical_learner  adaptive_satisficing
# 2417        2417                  sdss                   NaN
# 2450        2450                  sdss                   NaN
# 172          172  hierarchical_learner  adaptive_satisficing
# 273          273  hierarchical_learner  adaptive_satisficing
# 1090        1090  hierarchical_learner             threshold
# 1977        1977    baseline_reinforce                   NaN
# 2777        2777                  sdss                   NaN
# 2424        2424                  sdss                   NaN
# 2685        2685                  sdss                   NaN
# 3068        3068                  sdss                   NaN
# 2065        2065                  sdss                   NaN
# 2747        2747                  sdss                   NaN
# 2547        2547                  sdss                   NaN
# 219          219  hierarchical_learner  adaptive_satisficing
# 2125        2125                  sdss                   NaN
# 2896        2896                  sdss                   NaN
# 2837        2837                  sdss                   NaN
# 2801        2801                  sdss                   NaN
# 3050        3050                  sdss                   NaN
# 1791        1791                  lvoc                   NaN
# 2925        2925                  sdss                   NaN
# 2537        2537                  sdss                   NaN
# 2217        2217                  sdss                   NaN
# 2266        2266                  sdss                   NaN
# 2618        2618                  sdss                   NaN
# 844          844  hierarchical_learner             threshold
# 3039        3039                  sdss                   NaN
# 2941        2941                  sdss                   NaN
# 319          319  hierarchical_learner  adaptive_satisficing
# 1067        1067  hierarchical_learner             threshold
# 2988        2988                  sdss                   NaN
# 585          585  hierarchical_learner             threshold
# 1828        1828             reinforce                   NaN
# 2245        2245                  sdss                   NaN
# 1991        1991    baseline_reinforce                   NaN
# 2020        2020                  rssl                   NaN
# 771          771  hierarchical_learner             threshold
# 2927        2927                  sdss                   NaN
# 2924        2924                  sdss                   NaN
# 2869        2869                  sdss                   NaN
# 2016        2016                  rssl                   NaN
# 870          870  hierarchical_learner             threshold
# 2796        2796                  sdss                   NaN
# 2954        2954                  sdss                   NaN
# 2861        2861                  sdss                   NaN
# 94            94  hierarchical_learner  adaptive_satisficing
# 2958        2958                  sdss                   NaN
# 1733        1733                  lvoc                   NaN
# 2590        2590                  sdss                   NaN
# 2792        2792                  sdss                   NaN
# 602          602  hierarchical_learner             threshold
# 2557        2557                  sdss                   NaN
# 2029        2029                  rssl                   NaN
# 2717        2717                  sdss                   NaN
# 2365        2365                  sdss                   NaN
# 3120        3120                  sdss                   NaN
# 2310        2310                  sdss                   NaN
# 14            14  hierarchical_learner  adaptive_satisficing
# 403          403  hierarchical_learner  adaptive_satisficing
# 300          300  hierarchical_learner  adaptive_satisficing
# 2686        2686                  sdss                   NaN
# 414          414  hierarchical_learner  adaptive_satisficing
# 200          200  hierarchical_learner  adaptive_satisficing
# 346          346  hierarchical_learner  adaptive_satisficing
# 323          323  hierarchical_learner  adaptive_satisficing
# 2136        2136                  sdss                   NaN
# 2650        2650                  sdss                   NaN
# 3212        3212                  sdss                   NaN
# 2790        2790                  sdss                   NaN
# 2855        2855                  sdss                   NaN
# 1092        1092  hierarchical_learner             threshold
# 514          514  hierarchical_learner  adaptive_satisficing
# 3017        3017                  sdss                   NaN
# 2908        2908                  sdss                   NaN
# 2502        2502                  sdss                   NaN
# 1816        1816                  lvoc                   NaN
# 2222        2222                  sdss                   NaN
# 787          787  hierarchical_learner             threshold
# 2297        2297                  sdss                   NaN
# 2906        2906                  sdss                   NaN
# 399          399  hierarchical_learner  adaptive_satisficing
# 2086        2086                  sdss                   NaN
# 2218        2218                  sdss                   NaN
# 2283        2283                  sdss                   NaN
# 3173        3173                  sdss                   NaN
# 2699        2699                  sdss                   NaN
# 2051        2051                  rssl                   NaN
# 2154        2154                  sdss                   NaN
# 3208        3208                  sdss                   NaN
# 2730        2730                  sdss                   NaN
# 2448        2448                  sdss                   NaN
# 2280        2280                  sdss                   NaN
# 1843        1843             reinforce                   NaN
# 533          533  hierarchical_learner  adaptive_satisficing
# 98            98  hierarchical_learner  adaptive_satisficing
# 2460        2460                  sdss                   NaN
# 3031        3031                  sdss                   NaN
# 2017        2017                  rssl                   NaN
# 2127        2127                  sdss                   NaN
# 2506        2506                  sdss                   NaN
# 3180        3180                  sdss                   NaN
# 265          265  hierarchical_learner  adaptive_satisficing
# 2445        2445                  sdss                   NaN
# 805          805  hierarchical_learner             threshold
# 3110        3110                  sdss                   NaN
# 2971        2971                  sdss                   NaN
# 2974        2974                  sdss                   NaN
# 2813        2813                  sdss                   NaN
# 272          272  hierarchical_learner  adaptive_satisficing
# 2493        2493                  sdss                   NaN
# 2490        2490                  sdss                   NaN
# 2081        2081                  sdss                   NaN
# 2504        2504                  sdss                   NaN
# 2521        2521                  sdss                   NaN
# 2397        2397                  sdss                   NaN
# 2541        2541                  sdss                   NaN
# 2897        2897                  sdss                   NaN
# 1759        1759                  lvoc                   NaN
# 760          760  hierarchical_learner             threshold
# 2011        2011    baseline_reinforce                   NaN
# 2909        2909                  sdss                   NaN
# 2269        2269                  sdss                   NaN
# 397          397  hierarchical_learner  adaptive_satisficing
# 2376        2376                  sdss                   NaN
# 2856        2856                  sdss                   NaN
# 2571        2571                  sdss                   NaN
# 2318        2318                  sdss                   NaN
# 354          354  hierarchical_learner  adaptive_satisficing
# 28            28  hierarchical_learner  adaptive_satisficing
# 2350        2350                  sdss                   NaN
# 969          969  hierarchical_learner             threshold
# 163          163  hierarchical_learner  adaptive_satisficing
# 3199        3199                  sdss                   NaN
# 2697        2697                  sdss                   NaN
# 2905        2905                  sdss                   NaN
# 2928        2928                  sdss                   NaN
# 2173        2173                  sdss                   NaN
# 3032        3032                  sdss                   NaN
# 730          730  hierarchical_learner             threshold
# 1933        1933    baseline_reinforce                   NaN
# 2687        2687                  sdss                   NaN
# 2671        2671                  sdss                   NaN
# 564          564  hierarchical_learner  adaptive_satisficing
# 2160        2160                  sdss                   NaN
# 2153        2153                  sdss                   NaN
# 2421        2421                  sdss                   NaN
# 2466        2466                  sdss                   NaN
# 353          353  hierarchical_learner  adaptive_satisficing
# 2106        2106                  sdss                   NaN
# 2039        2039                  rssl                   NaN
# 2036        2036                  rssl                   NaN
# 2700        2700                  sdss                   NaN
# 541          541  hierarchical_learner  adaptive_satisficing
# 321          321  hierarchical_learner  adaptive_satisficing
# 2334        2334                  sdss                   NaN
# 2743        2743                  sdss                   NaN
# 2904        2904                  sdss                   NaN
# 1812        1812                  lvoc                   NaN
# 2844        2844                  sdss                   NaN
# 1831        1831             reinforce                   NaN
# 3101        3101                  sdss                   NaN
# 3160        3160                  sdss                   NaN
# 1983        1983    baseline_reinforce                   NaN
# 2480        2480                  sdss                   NaN
# 2157        2157                  sdss                   NaN
# 2973        2973                  sdss                   NaN
# 2155        2155                  sdss                   NaN
# 2638        2638                  sdss                   NaN
# 2047        2047                  rssl                   NaN
# 591          591  hierarchical_learner             threshold
# 594          594  hierarchical_learner             threshold
# 3147        3147                  sdss                   NaN
# 3146        3146                  sdss                   NaN
# 81            81  hierarchical_learner  adaptive_satisficing
# 2556        2556                  sdss                   NaN
# 2959        2959                  sdss                   NaN
# 1821        1821                  lvoc                   NaN
# 2985        2985                  sdss                   NaN
# 316          316  hierarchical_learner  adaptive_satisficing
# 582          582  hierarchical_learner             threshold
# 2363        2363                  sdss                   NaN
# 2950        2950                  sdss                   NaN
# 1774        1774                  lvoc                   NaN
# 2901        2901                  sdss                   NaN
# 2875        2875                  sdss                   NaN
# 587          587  hierarchical_learner             threshold
# 3179        3179                  sdss                   NaN
# 2409        2409                  sdss                   NaN
# 2468        2468                  sdss                   NaN
# 1980        1980    baseline_reinforce                   NaN
# 154          154  hierarchical_learner  adaptive_satisficing
# 2313        2313                  sdss                   NaN
# 2633        2633                  sdss                   NaN
# 2316        2316                  sdss                   NaN
# 2489        2489                  sdss                   NaN
# 2019        2019                  rssl                   NaN
# 2845        2845                  sdss                   NaN
# 2344        2344                  sdss                   NaN
# 2682        2682                  sdss                   NaN
# 988          988  hierarchical_learner             threshold
# 928          928  hierarchical_learner             threshold
# 146          146  hierarchical_learner  adaptive_satisficing
# 350          350  hierarchical_learner  adaptive_satisficing
# 2529        2529                  sdss                   NaN
# 2186        2186                  sdss                   NaN
# 2271        2271                  sdss                   NaN
# 3181        3181                  sdss                   NaN
# 2526        2526                  sdss                   NaN
# 258          258  hierarchical_learner  adaptive_satisficing
# 2281        2281                  sdss                   NaN
# 139          139  hierarchical_learner  adaptive_satisficing
# 1777        1777                  lvoc                   NaN
# 2698        2698                  sdss                   NaN
# 2809        2809                  sdss                   NaN
# 2364        2364                  sdss                   NaN
# 343          343  hierarchical_learner  adaptive_satisficing
# 2559        2559                  sdss                   NaN
# 3185        3185                  sdss                   NaN
# 580          580  hierarchical_learner             threshold
# 2471        2471                  sdss                   NaN
# 2302        2302                  sdss                   NaN
# 3144        3144                  sdss                   NaN
# 2987        2987                  sdss                   NaN
# 3002        3002                  sdss                   NaN
# 1734        1734                  lvoc                   NaN
# 2399        2399                  sdss                   NaN
# 12            12  hierarchical_learner  adaptive_satisficing
# 333          333  hierarchical_learner  adaptive_satisficing
# 2810        2810                  sdss                   NaN
# 2232        2232                  sdss                   NaN
# 2422        2422                  sdss                   NaN
# 3178        3178                  sdss                   NaN
# 2064        2064                  sdss                   NaN
# 1783        1783                  lvoc                   NaN
# 1131        1131  hierarchical_learner             threshold
# 2299        2299                  sdss                   NaN
# 1830        1830             reinforce                   NaN
# 2126        2126                  sdss                   NaN
# 2538        2538                  sdss                   NaN
# 1770        1770                  lvoc                   NaN
# 605          605  hierarchical_learner             threshold
# 437          437  hierarchical_learner  adaptive_satisficing
# 261          261  hierarchical_learner  adaptive_satisficing
# 2438        2438                  sdss                   NaN
# 2670        2670                  sdss                   NaN
# 1757        1757                  lvoc                   NaN
# 2459        2459                  sdss                   NaN
# 892          892  hierarchical_learner             threshold
# 2312        2312                  sdss                   NaN
# 3165        3165                  sdss                   NaN
# 489          489  hierarchical_learner  adaptive_satisficing
# 330          330  hierarchical_learner  adaptive_satisficing
# 2060        2060                  rssl                   NaN
# 400          400  hierarchical_learner  adaptive_satisficing
# 2997        2997                  sdss                   NaN
# 3150        3150                  sdss                   NaN
# 3053        3053                  sdss                   NaN
# 2236        2236                  sdss                   NaN
# 2156        2156                  sdss                   NaN
# 2398        2398                  sdss                   NaN
# 2012        2012    baseline_reinforce                   NaN
# 2617        2617                  sdss                   NaN
# 3082        3082                  sdss                   NaN
# 2865        2865                  sdss                   NaN
# 391          391  hierarchical_learner  adaptive_satisficing
# 2360        2360                  sdss                   NaN
# 1776        1776                  lvoc                   NaN
# 19            19  hierarchical_learner  adaptive_satisficing
# 3085        3085                  sdss                   NaN
# 3129        3129                  sdss                   NaN
# 2797        2797                  sdss                   NaN
# 2802        2802                  sdss                   NaN
# 2607        2607                  sdss                   NaN
# 218          218  hierarchical_learner  adaptive_satisficing
# 2990        2990                  sdss                   NaN
# 3067        3067                  sdss                   NaN
# 3118        3118                  sdss                   NaN
# 2554        2554                  sdss                   NaN
# 2525        2525                  sdss                   NaN
# 975          975  hierarchical_learner             threshold
# 259          259  hierarchical_learner  adaptive_satisficing
# 3148        3148                  sdss                   NaN
# 347          347  hierarchical_learner  adaptive_satisficing
# 2724        2724                  sdss                   NaN
# 2639        2639                  sdss                   NaN
# 2545        2545                  sdss                   NaN
# 2152        2152                  sdss                   NaN
# 2749        2749                  sdss                   NaN
# 2858        2858                  sdss                   NaN
# 2991        2991                  sdss                   NaN
# 2378        2378                  sdss                   NaN
# 2603        2603                  sdss                   NaN
# 2725        2725                  sdss                   NaN
# 2763        2763                  sdss                   NaN
# 983          983  hierarchical_learner             threshold
# 401          401  hierarchical_learner  adaptive_satisficing
# 31            31  hierarchical_learner  adaptive_satisficing
# 2486        2486                  sdss                   NaN
# 2203        2203                  sdss                   NaN
# 468          468  hierarchical_learner  adaptive_satisficing
# 413          413  hierarchical_learner  adaptive_satisficing
# 18            18  hierarchical_learner  adaptive_satisficing
# 1040        1040  hierarchical_learner             threshold
# 2090        2090                  sdss                   NaN
# 2107        2107                  sdss                   NaN
# 1775        1775                  lvoc                   NaN
# 206          206  hierarchical_learner  adaptive_satisficing
# 3116        3116                  sdss                   NaN
# 3027        3027                  sdss                   NaN
# 3193        3193                  sdss                   NaN
# 1736        1736                  lvoc                   NaN
# 791          791  hierarchical_learner             threshold
# 2811        2811                  sdss                   NaN
# 16            16  hierarchical_learner  adaptive_satisficing
# 1912        1912             reinforce                   NaN
# 2332        2332                  sdss                   NaN
# 385          385  hierarchical_learner  adaptive_satisficing
# 3036        3036                  sdss                   NaN
# 2843        2843                  sdss                   NaN
# 27            27  hierarchical_learner  adaptive_satisficing
# 2446        2446                  sdss                   NaN
# 2005        2005    baseline_reinforce                   NaN
# 450          450  hierarchical_learner  adaptive_satisficing
# 649          649  hierarchical_learner             threshold
# 1822        1822                  lvoc                   NaN
# 3182        3182                  sdss                   NaN
# 3023        3023                  sdss                   NaN
# 15            15  hierarchical_learner  adaptive_satisficing
# 2890        2890                  sdss                   NaN
# 1095        1095  hierarchical_learner             threshold
# 465          465  hierarchical_learner  adaptive_satisficing
# 786          786  hierarchical_learner             threshold
# 2458        2458                  sdss                   NaN
# 2517        2517                  sdss                   NaN
# 2649        2649                  sdss                   NaN
# 1743        1743                  lvoc                   NaN
# 194          194  hierarchical_learner  adaptive_satisficing
# 3081        3081                  sdss                   NaN
# 402          402  hierarchical_learner  adaptive_satisficing
# 2              2  hierarchical_learner  adaptive_satisficing
# 351          351  hierarchical_learner  adaptive_satisficing
# 2798        2798                  sdss                   NaN
# 2461        2461                  sdss                   NaN
# 394          394  hierarchical_learner  adaptive_satisficing
# 1887        1887             reinforce                   NaN
# 384          384  hierarchical_learner  adaptive_satisficing
# 74            74  hierarchical_learner  adaptive_satisficing
# 512          512  hierarchical_learner  adaptive_satisficing
# 87            87  hierarchical_learner  adaptive_satisficing
# 537          537  hierarchical_learner  adaptive_satisficing
#
#       use_pseudo_rewards  pr_weight               actor   term selector  \
# 2589                True      False                 NaN   True     rssl
# 2082                True       True                 NaN   True     rssl
# 2476                True      False                 NaN   True     rssl
# 2089                True       True                 NaN   True     rssl
# 153                 True       True  baseline_reinforce   True      NaN
# 2227                True       True                 NaN   True     rssl
# 2667                True      False                 NaN   True     rssl
# 192                 True      False                lvoc   True      NaN
# 2836               False      False                 NaN   True     rssl
# 199                 True      False                lvoc   True      NaN
# 2668                True      False                 NaN   True     rssl
# 2059               False      False                 NaN    NaN      NaN
# 2652                True      False                 NaN   True     rssl
# 1997               False      False                 NaN   True      NaN
# 104                 True       True           reinforce  False      NaN
# 739                 True       True  baseline_reinforce  False      NaN
# 2429                True       True                 NaN   True     rssl
# 2940               False      False                 NaN   True     rssl
# 2778                True      False                 NaN   True     rssl
# 2104                True       True                 NaN   True     rssl
# 2418                True       True                 NaN   True     rssl
# 2948               False      False                 NaN   True     rssl
# 1739                True       True                 NaN   True      NaN
# 1928                True       True                 NaN   True      NaN
# 2184                True       True                 NaN   True     rssl
# 3198               False      False                 NaN   True     rssl
# 2330                True       True                 NaN   True     rssl
# 2121                True       True                 NaN   True     rssl
# 3114               False      False                 NaN   True     rssl
# 1989               False      False                 NaN   True      NaN
# 2712                True      False                 NaN   True     rssl
# 1125               False      False  baseline_reinforce  False      NaN
# 3130               False      False                 NaN   True     rssl
# 1742                True       True                 NaN   True      NaN
# 2707                True      False                 NaN   True     rssl
# 2108                True       True                 NaN   True     rssl
# 419                False      False                lvoc  False      NaN
# 1042               False      False           reinforce   True      NaN
# 2568                True      False                 NaN   True     rssl
# 2706                True      False                 NaN   True     rssl
# 2491                True      False                 NaN   True     rssl
# 366                 True      False  baseline_reinforce  False      NaN
# 2073                True       True                 NaN   True     rssl
# 1964                True      False                 NaN   True      NaN
# 140                 True       True  baseline_reinforce   True      NaN
# 225                 True      False                lvoc  False      NaN
# 970                False      False                lvoc   True      NaN
# 2235                True       True                 NaN   True     rssl
# 2148                True       True                 NaN   True     rssl
# 2774                True      False                 NaN   True     rssl
# 2696                True      False                 NaN   True     rssl
# 2393                True       True                 NaN   True     rssl
# 43                  True       True                lvoc  False      NaN
# 426                False      False                lvoc  False      NaN
# 2655                True      False                 NaN   True     rssl
# 2338                True       True                 NaN   True     rssl
# 2201                True       True                 NaN   True     rssl
# 2602                True      False                 NaN   True     rssl
# 2936               False      False                 NaN   True     rssl
# 2454                True      False                 NaN   True     rssl
# 3119               False      False                 NaN   True     rssl
# 3040               False      False                 NaN   True     rssl
# 2641                True      False                 NaN   True     rssl
# 2558                True      False                 NaN   True     rssl
# 683                 True       True           reinforce  False      NaN
# 129                 True       True  baseline_reinforce   True      NaN
# 1780                True      False                 NaN   True      NaN
# 2731                True      False                 NaN   True     rssl
# 1730                True       True                 NaN   True      NaN
# 3084               False      False                 NaN   True     rssl
# 2228                True       True                 NaN   True     rssl
# 380                 True      False  baseline_reinforce  False      NaN
# 2625                True      False                 NaN   True     rssl
# 1999               False      False                 NaN   True      NaN
# 3063               False      False                 NaN   True     rssl
# 2737                True      False                 NaN   True     rssl
# 2162                True       True                 NaN   True     rssl
# 2100                True       True                 NaN   True     rssl
# 2078                True       True                 NaN   True     rssl
# 2807                True      False                 NaN   True     rssl
# 3163               False      False                 NaN   True     rssl
# 960                False      False                lvoc   True      NaN
# 2279                True       True                 NaN   True     rssl
# 767                 True       True  baseline_reinforce  False      NaN
# 281                 True      False           reinforce   True      NaN
# 305                 True      False           reinforce  False      NaN
# 2085                True       True                 NaN   True     rssl
# 128                 True       True  baseline_reinforce   True      NaN
# 936                 True      False  baseline_reinforce  False      NaN
# 2434                True       True                 NaN   True     rssl
# 2860               False      False                 NaN   True     rssl
# 2115                True       True                 NaN   True     rssl
# 565                False      False  baseline_reinforce  False      NaN
# 2479                True      False                 NaN   True     rssl
# 201                 True      False                lvoc   True      NaN
# 2779                True      False                 NaN   True     rssl
# 2666                True      False                 NaN   True     rssl
# 978                False      False                lvoc   True      NaN
# 2715                True      False                 NaN   True     rssl
# 2870               False      False                 NaN   True     rssl
# 2456                True      False                 NaN   True     rssl
# 9                   True       True                lvoc   True      NaN
# 2465                True      False                 NaN   True     rssl
# 555                False      False  baseline_reinforce  False      NaN
# 1885                True      False                 NaN   True      NaN
# 236                 True      False                lvoc  False      NaN
# 2814                True      False                 NaN   True     rssl
# 729                 True       True  baseline_reinforce   True      NaN
# 2335                True       True                 NaN   True     rssl
# 2425                True       True                 NaN   True     rssl
# 2211                True       True                 NaN   True     rssl
# 1065               False      False           reinforce  False      NaN
# ...
# 3053              False     True       False         True  strategy_weight
# 2236              False     True        True         True  strategy_weight
# 2156              False     True        True         True  strategy_weight
# 2398              False    False        True         True  strategy_weight
# 2012               True     True         NaN          NaN  strategy_weight
# 2617               True     True       False         True  strategy_weight
# 3082               True    False        True         True  strategy_weight
# 2865               True     True       False         True  strategy_weight
# 391               False    False         NaN          NaN  strategy_weight
# 2360               True     True        True         True  strategy_weight
# 1776               True     True         NaN          NaN  strategy_weight
# 19                False    False         NaN          NaN  strategy_weight
# 3085              False     True       False         True  strategy_weight
# 3129               True     True       False         True  strategy_weight
# 2797              False     True       False         True  strategy_weight
# 2802               True    False        True         True  strategy_weight
# 2607              False    False       False         True  strategy_weight
# 218               False     True         NaN          NaN  strategy_weight
# 2990              False    False        True         True  strategy_weight
# 3067               True    False       False         True  strategy_weight
# 3118              False    False        True         True  strategy_weight
# 2554               True    False        True         True  strategy_weight
# 2525              False     True       False         True  strategy_weight
# 975               False    False         NaN          NaN  strategy_weight
# 259               False    False         NaN          NaN  strategy_weight
# 3148              False     True        True         True  strategy_weight
# 347               False    False         NaN          NaN  strategy_weight
# 2724              False     True        True         True  strategy_weight
# 2639              False    False       False         True  strategy_weight
# 2545               True     True       False         True  strategy_weight
# 2152               True     True        True         True  strategy_weight
# 2749              False     True       False         True  strategy_weight
# 2858               True    False        True         True  strategy_weight
# 2991              False    False       False         True  strategy_weight
# 2378               True    False        True         True  strategy_weight
# 2603               True    False       False         True  strategy_weight
# 2725              False     True       False         True  strategy_weight
# 2763               True    False       False         True  strategy_weight
# 983               False    False         NaN          NaN  strategy_weight
# 401                True    False         NaN          NaN  strategy_weight
# 31                False    False         NaN          NaN  strategy_weight
# 2486              False    False        True         True  strategy_weight
# 2203               True    False       False         True  strategy_weight
# 468                True     True         NaN          NaN  strategy_weight
# 413                True    False         NaN          NaN  strategy_weight
# 18                False     True         NaN          NaN  strategy_weight
# 1040               True     True         NaN          NaN  strategy_weight
# 2090               True    False        True         True  strategy_weight
# 2107               True    False       False         True  strategy_weight
# 1775              False    False         NaN          NaN  strategy_weight
# 206               False     True         NaN          NaN  strategy_weight
# 3116              False     True        True         True  strategy_weight
# 3027               True    False       False         True  strategy_weight
# 3193               True     True       False         True  strategy_weight
# 1736               True     True         NaN          NaN  strategy_weight
# 791               False    False         NaN          NaN  strategy_weight
# 2811               True    False       False         True  strategy_weight
# 16                 True     True         NaN          NaN  strategy_weight
# 1912               True     True         NaN          NaN  strategy_weight
# 2332              False     True        True         True  strategy_weight
# 385                True    False         NaN          NaN  strategy_weight
# 3036              False     True        True         True  strategy_weight
# 2843               True    False       False         True  strategy_weight
# 27                False    False         NaN          NaN  strategy_weight
# 2446              False    False        True         True  strategy_weight
# 2005               True    False         NaN          NaN  strategy_weight
# 450               False     True         NaN          NaN  strategy_weight
# 649                True    False         NaN          NaN  strategy_weight
# 1822              False     True         NaN          NaN  strategy_weight
# 3182              False    False        True         True  strategy_weight
# 3023              False    False       False         True  strategy_weight
# 15                False    False         NaN          NaN  strategy_weight
# 2890               True    False        True         True  strategy_weight
# 1095              False    False         NaN          NaN  strategy_weight
# 465                True    False         NaN          NaN  strategy_weight
# 786               False     True         NaN          NaN  strategy_weight
# 2458               True    False        True         True  strategy_weight
# 2517              False     True       False         True  strategy_weight
# 2649               True     True       False         True  strategy_weight
# 1743              False    False         NaN          NaN  strategy_weight
# 194               False     True         NaN          NaN  strategy_weight
# 3081               True     True       False         True  strategy_weight
# 402               False     True         NaN          NaN  strategy_weight
# 2                 False     True         NaN          NaN  strategy_weight
# 351               False    False         NaN          NaN  strategy_weight
# 2798              False    False        True         True  strategy_weight
# 2461              False     True       False         True  strategy_weight
# 394               False     True         NaN          NaN  strategy_weight
# 1887              False    False         NaN          NaN  strategy_weight
# 384                True     True         NaN          NaN  strategy_weight
# 74                False     True         NaN          NaN  strategy_weight
# 512                True     True         NaN          NaN  strategy_weight
# 87                False    False         NaN          NaN  strategy_weight
# 537                True    False         NaN          NaN  strategy_weight
#
#           r
# 2589  35.00
# 2082  35.00
# 2476  34.98
# 2089  34.98
# 153   34.97
# 2227  34.96
# 2667  34.96
# 192   34.96
# 2836  34.96
# 199   34.95
# 2668  34.94
# 2059  34.94
# 2652  34.94
# 1997  34.94
# 104   34.93
# 739   34.93
# 2429  34.92
# 2940  34.92
# 2778  34.91
# 2104  34.90
# 2418  34.90
# 2948  34.90
# 1739  34.90
# 1928  34.90
# 2184  34.89
# 3198  34.88
# 2330  34.88
# 2121  34.88
# 3114  34.88
# 1989  34.88
# 2712  34.87
# 1125  34.87
# 3130  34.86
# 1742  34.86
# 2707  34.86
# 2108  34.84
# 419   34.84
# 1042  34.84
# 2568  34.84
# 2706  34.84
# 2491  34.84
# 366   34.83
# 2073  34.82
# 1964  34.82
# 140   34.82
# 225   34.81
# 970   34.80
# 2235  34.79
# 2148  34.79
# 2774  34.79
# 2696  34.79
# 2393  34.79
# 43    34.78
# 426   34.78
# 2655  34.78
# 2338  34.78
# 2201  34.77
# 2602  34.77
# 2936  34.76
# 2454  34.76
# 3119  34.74
# 3040  34.74
# 2641  34.73
# 2558  34.73
# 683   34.73
# 129   34.72
# 1780  34.72
# 2731  34.71
# 1730  34.71
# 3084  34.70
# 2228  34.70
# 380   34.69
# 2625  34.69
# 1999  34.69
# 3063  34.69
# 2737  34.69
# 2162  34.68
# 2100  34.68
# 2078  34.67
# 2807  34.67
# 3163  34.65
# 960   34.65
# 2279  34.63
# 767   34.63
# 281   34.63
# 305   34.62
# 2085  34.62
# 128   34.62
# 936   34.62
# 2434  34.61
# 2860  34.61
# 2115  34.61
# 565   34.60
# 2479  34.60
# 201   34.60
# 2779  34.59
# 2666  34.59
# 978   34.59
# 2715  34.58
# 2870  34.57
# 2456  34.57
# 9     34.56
# 2465  34.56
# 555   34.55
# 1885  34.55
# 236   34.53
# 2814  34.52
# 729   34.52
# 2335  34.52
# 2425  34.52
# 2211  34.51
# 1065  34.51
# 2989  34.51
# 1965  34.50
# 3088  34.50
# 2091  34.49
# 1771  34.49
# 340   34.49
# 2349  34.48
# 2431  34.48
# 798   34.47
# 2405  34.47
# 3096  34.46
# 2672  34.46
# 2937  34.45
# 2488  34.45
# 2505  34.44
# 2921  34.42
# 2735  34.41
# 2390  34.41
# 2190  34.40
# 2440  34.40
# 2511  34.40
# 2382  34.40
# 2570  34.40
# 193   34.40
# 1823  34.39
# 3022  34.38
# 2251  34.38
# 3046  34.38
# 777   34.37
# 2049  34.36
# 2939  34.36
# 369   34.36
# 2584  34.35
# 370   34.34
# 2512  34.34
# 1772  34.33
# 882   34.33
# 1955  34.32
# 2573  34.32
# 2902  34.32
# 2544  34.31
# 2441  34.31
# 957   34.30
# 1754  34.30
# 869   34.30
# 449   34.30
# 1063  34.29
# 30    34.29
# 2733  34.28
# 2170  34.28
# 3070  34.27
# 3051  34.27
# 3065  34.26
# 1756  34.26
# 3132  34.26
# 2453  34.26
# 2124  34.26
# 2820  34.25
# 3077  34.25
# 1781  34.25
# 1819  34.25
# 2664  34.24
# 2285  34.24
# 775   34.23
# 989   34.22
# 459   34.22
# 3045  34.22
# 550   34.21
# 2272  34.21
# 3211  34.21
# 72    34.20
# 2965  34.20
# 719   34.20
# 2255  34.19
# 2665  34.19
# 1803  34.19
# 3133  34.18
# 190   34.18
# 2296  34.17
# 1     34.17
# 2751  34.17
# 2894  34.17
# 1118  34.16
# 2539  34.16
# 596   34.16
# 2301  34.15
# 2234  34.15
# 1782  34.14
# 2781  34.14
# 2793  34.13
# 911   34.13
# 2701  34.13
# 961   34.13
# 751   34.12
# 2934  34.12
# 3015  34.12
# 2549  34.12
# 2487  34.12
# 2953  34.11
# 1849  34.11
# 157   34.11
# 2981  34.10
# 2178  34.09
# 2109  34.08
# 2093  34.08
# 2766  34.08
# 2473  34.07
# 386   34.04
# 3038  34.04
# 2606  34.04
# 2379  34.03
# 2305  34.02
# 363   34.02
# 1741  34.01
# 2888  34.01
# 2748  34.01
# 2824  34.00
# 2658  34.00
# 2588  33.99
# 21    33.99
# 2027  33.99
# 1841  33.99
# 3099  33.99
# 1840  33.98
# 2876  33.97
# 2575  33.97
# 2723  33.97
# 2135  33.96
# 3168  33.96
# 2728  33.95
# 2253  33.94
# 2872  33.94
# 927   33.93
# 2410  33.93
# 2088  33.92
# 2893  33.92
# 2329  33.92
# 55    33.90
# 874   33.89
# 3209  33.88
# 2408  33.88
# 972   33.86
# 3117  33.84
# 2968  33.84
# 2074  33.84
# 2957  33.83
# 3135  33.83
# 2430  33.83
# 2532  33.83
# 2254  33.82
# 2477  33.82
# 2452  33.81
# 1908  33.80
# 67    33.80
# 2417  33.79
# 2450  33.79
# 172   33.79
# 273   33.78
# 1090  33.78
# 1977  33.77
# 2777  33.76
# 2424  33.75
# 2685  33.73
# 3068  33.73
# 2065  33.73
# 2747  33.72
# 2547  33.71
# 219   33.71
# 2125  33.71
# 2896  33.70
# 2837  33.70
# 2801  33.69
# 3050  33.68
# 1791  33.68
# 2925  33.68
# 2537  33.68
# 2217  33.67
# 2266  33.67
# 2618  33.66
# 844   33.66
# 3039  33.65
# 2941  33.64
# 319   33.64
# 1067  33.64
# 2988  33.63
# 585   33.62
# 1828  33.62
# 2245  33.61
# 1991  33.60
# 2020  33.60
# 771   33.60
# 2927  33.60
# 2924  33.59
# 2869  33.59
# 2016  33.59
# 870   33.58
# 2796  33.56
# 2954  33.56
# 2861  33.56
# 94    33.55
# 2958  33.55
# 1733  33.53
# 2590  33.52
# 2792  33.52
# 602   33.52
# 2557  33.51
# 2029  33.51
# 2717  33.51
# 2365  33.50
# 3120  33.49
# 2310  33.49
# 14    33.49
# 403   33.49
# 300   33.49
# 2686  33.48
# 414   33.48
# 200   33.47
# 346   33.46
# 323   33.46
# 2136  33.45
# 2650  33.44
# 3212  33.44
# 2790  33.42
# 2855  33.40
# 1092  33.40
# 514   33.40
# 3017  33.40
# 2908  33.40
# 2502  33.38
# 1816  33.35
# 2222  33.35
# 787   33.34
# 2297  33.34
# 2906  33.33
# 399   33.33
# 2086  33.32
# 2218  33.31
# 2283  33.30
# 3173  33.29
# 2699  33.28
# 2051  33.28
# 2154  33.27
# 3208  33.27
# 2730  33.25
# 2448  33.25
# 2280  33.24
# 1843  33.24
# 533   33.23
# 98    33.23
# 2460  33.22
# 3031  33.22
# 2017  33.22
# 2127  33.21
# 2506  33.20
# 3180  33.20
# 265   33.19
# 2445  33.19
# 805   33.17
# 3110  33.16
# 2971  33.16
# 2974  33.14
# 2813  33.13
# 272   33.13
# 2493  33.11
# 2490  33.11
# 2081  33.11
# 2504  33.10
# 2521  33.09
# 2397  33.08
# 2541  33.08
# 2897  33.07
# 1759  33.07
# 760   33.07
# 2011  33.07
# 2909  33.06
# 2269  33.06
# 397   33.06
# 2376  33.06
# 2856  33.05
# 2571  33.05
# 2318  33.04
# 354   33.03
# 28    33.03
# 2350  33.02
# 969   33.01
# 163   33.00
# 3199  32.99
# 2697  32.99
# 2905  32.99
# 2928  32.98
# 2173  32.98
# 3032  32.97
# 730   32.96
# 1933  32.96
# 2687  32.95
# 2671  32.95
# 564   32.94
# 2160  32.94
# 2153  32.93
# 2421  32.93
# 2466  32.91
# 353   32.91
# 2106  32.90
# 2039  32.90
# 2036  32.88
# 2700  32.88
# 541   32.87
# 321   32.86
# 2334  32.86
# 2743  32.85
# 2904  32.84
# 1812  32.84
# 2844  32.83
# 1831  32.82
# 3101  32.82
# 3160  32.82
# 1983  32.82
# 2480  32.82
# 2157  32.81
# 2973  32.80
# 2155  32.74
# 2638  32.73
# 2047  32.72
# 591   32.71
# 594   32.70
# 3147  32.69
# 3146  32.69
# 81    32.68
# 2556  32.68
# 2959  32.66
# 1821  32.66
# 2985  32.66
# 316   32.66
# 582   32.64
# 2363  32.63
# 2950  32.61
# 1774  32.61
# 2901  32.60
# 2875  32.59
# 587   32.57
# 3179  32.56
# 2409  32.54
# 2468  32.52
# 1980  32.52
# 154   32.51
# 2313  32.50
# 2633  32.48
# 2316  32.48
# 2489  32.48
# 2019  32.44
# 2845  32.44
# 2344  32.43
# 2682  32.43
# 988   32.43
# 928   32.42
# 146   32.39
# 350   32.37
# 2529  32.36
# 2186  32.35
# 2271  32.35
# 3181  32.33
# 2526  32.32
# 258   32.32
# 2281  32.31
# 139   32.29
# 1777  32.29
# 2698  32.27
# 2809  32.27
# 2364  32.26
# 343   32.23
# 2559  32.23
# 3185  32.22
# 580   32.22
# 2471  32.20
# 2302  32.19
# 3144  32.19
# 2987  32.18
# 3002  32.18
# 1734  32.14
# 2399  32.13
# 12    32.13
# 333   32.12
# 2810  32.10
# 2232  32.10
# 2422  32.10
# 3178  32.09
# 2064  32.09
# 1783  32.08
# 1131  32.07
# 2299  32.04
# 1830  32.03
# 2126  32.03
# 2538  32.00
# 1770  32.00
# 605   32.00
# 437   31.99
# 261   31.97
# 2438  31.96
# 2670  31.95
# 1757  31.92
# 2459  31.92
# 892   31.90
# 2312  31.89
# 3165  31.86
# 489   31.85
# 330   31.85
# 2060  31.84
# 400   31.81
# 2997  31.79
# 3150  31.79
# 3053  31.78
# 2236  31.78
# 2156  31.77
# 2398  31.73
# 2012  31.71
# 2617  31.66
# 3082  31.66
# 2865  31.64
# 391   31.62
# 2360  31.61
# 1776  31.49
# 19    31.47
# 3085  31.47
# 3129  31.46
# 2797  31.46
# 2802  31.46
# 2607  31.42
# 218   31.39
# 2990  31.39
# 3067  31.37
# 3118  31.36
# 2554  31.34
# 2525  31.33
# 975   31.28
# 259   31.25
# 3148  31.23
# 347   31.22
# 2724  31.20
# 2639  31.18
# 2545  31.14
# 2152  31.11
# 2749  31.10
# 2858  31.06
# 2991  31.04
# 2378  31.03
# 2603  31.01
# 2725  30.97
# 2763  30.92
# 983   30.92
# 401   30.92
# 31    30.91
# 2486  30.91
# 2203  30.90
# 468   30.89
# 413   30.87
# 18    30.86
# 1040  30.82
# 2090  30.81
# 2107  30.66
# 1775  30.66
# 206   30.63
# 3116  30.61
# 3027  30.61
# 3193  30.60
# 1736  30.56
# 791   30.56
# 2811  30.55
# 16    30.52
# 1912  30.51
# 2332  30.51
# 385   30.49
# 3036  30.45
# 2843  30.44
# 27    30.44
# 2446  30.38
# 2005  30.08
# 450   30.03
# 649   30.00
# 1822  29.99
# 3182  29.93
# 3023  29.87
# 15    29.84
# 2890  29.70
# 1095  29.70
# 465   29.66
# 786   29.65
# 2458  29.56
# 2517  29.52
# 2649  29.36
# 1743  29.31
# 194   29.21
# 3081  29.19
# 402   29.18
# 2     29.09
# 351   28.81
# 2798  28.56
# 2461  28.48
# 394   28.44
# 1887  27.92
# 384   27.26
# 74    27.17
# 512   26.66
# 87    24.19
# 537   23.52

# %%
print(df.groupby(['model'])['r'].mean())
# Out:
# model
# baseline_reinforce      33.572000
# hierarchical_learner    32.854356
# lvoc                    33.096129
# reinforce               32.779091
# rssl                    33.328462
# sdss                    33.329922
# Name: r, dtype: float64

# %%
sns.distplot(df['r'].tolist())

# %%
import pandas as pd
import seaborn as sns
import numpy as np
control_pids = [1, 2, 6, 9, 11, 14, 18, 21, 24, 27, 37, 38, 44, 50, 55, 56, 58, 66, 76, 79, 85, 89, 90, 98, 99,
                100, 104, 111, 113, 118, 119, 123, 126, 129, 139, 142, 144, 153, 154]
models = [0, 1, 64, 65, 128, 129, 576, 577, 640, 641, 704, 705, 1824, 1825, 1728, 1729, 1920, 1921]
create_dir("results/model_plots")
p_vals = []
m_vals = []
n_trials = 30
for model in models:
    data = pd.DataFrame()
    for pid in control_pids:
    #     for model in models:
        try:
            d = pickle_load(f"results/model_run_results/{pid}_mer_performance_error_{model}.pkl")
            data = data.append(d, ignore_index=True)
        except Exception as e:
            continue
    ax = sns.lineplot(x="x", y="y", hue = "algo", data=data)
    #plt.savefig(f"results/model_plots/{model}.png", bbox_inches='tight')
    plt.title(model)
    plt.show()

# %%
import pandas as pd
import seaborn as sns
import numpy as np
control_pids = [1, 2, 6, 9, 11, 14, 18, 21, 24, 27, 37, 38, 44, 50, 55, 56, 58, 66, 76, 79, 85, 89, 90, 98, 99,
                100, 104, 111, 113, 118, 119, 123, 126, 129, 139, 142, 144, 153, 154]
models = [0, 1, 64, 65, 128, 129, 576, 577, 640, 641, 704, 705, 1824, 1825, 1728, 1729, 1920, 1921]
create_dir("results/model_plots_microscope")
p_vals = []
m_vals = []
n_trials = 30
for model in models:
    data = pd.DataFrame()
    for pid in control_pids:
    #     for model in models:
        try:
            d = pickle_load(f"results/model_run_results_microscope/{pid}_mer_performance_error_{model}.pkl")
            data = data.append(d, ignore_index=True)
        except Exception as e:
            continue
    ax = sns.lineplot(x="x", y="y", hue = "algo", data=data)
    #plt.savefig(f"results/model_plots/{model}.png", bbox_inches='tight')
    plt.title(model)
    plt.show()

# %%
import pandas as pd
import seaborn as sns
import numpy as np
control_pids = [1, 2, 6, 9, 11, 14, 18, 21, 24, 27, 37, 38, 44, 50, 55, 56, 58, 66, 76, 79, 85, 89, 90, 98, 99,
                100, 104, 111, 113, 118, 119, 123, 126, 129, 139, 142, 144, 153, 154]
models = [0, 1, 64, 65, 128, 129, 576, 577, 640, 641, 704, 705, 1824, 1825, 1728, 1729, 1920, 1921]
create_dir("results/model_plots")
p_vals = []
m_vals = []
n_trials = 30
for i, pid in enumerate(control_pids):
    data = pd.DataFrame()
    m_data = {}
    diffs = []
    j = 0
    for model in models:
    #     for model in models:
        try:
            d = pickle_load(f"results/model_run_results/{pid}_mer_performance_error_{model}.pkl")
            data = data.append(d, ignore_index=True)
            mean_data = data.groupby(["algo", "x"]).mean()
            square = list(map(lambda x, y: (x-y)**2, mean_data['y']['algo'], mean_data['y']['participant']))
            p_val = mean_data['y']['participant'].values
            diff = np.sqrt(np.sum(square))
            diffs.append(diff)
            m_data[j] = mean_data
            j+=1
        except Exception as e:
            continue
    m_val = m_data[np.argmin(diffs)]["y"]["algo"].values
    if len(p_val) == n_trials and len(m_val) == n_trials:
        p_vals.append(p_val)
        m_vals.append(m_val)
#ax = sns.lineplot(x="x", y="y", hue = "algo", data=data)
plt.plot(range(1, len(p_val)+1), np.mean(p_vals, axis=0), label = "P") 
plt.plot(range(1, len(p_val)+1), np.mean(m_vals, axis=0), label = "M") 
plt.legend()
#plt.savefig(f"results/model_plots/{model}.png", bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import numpy as np
control_pids = [1, 2, 6, 9, 11, 14, 18, 21, 24, 27, 37, 38, 44, 50, 55, 56, 58, 66, 76, 79, 85, 89, 90, 98, 99,
                100, 104, 111, 113, 118, 119, 123, 126, 129, 139, 142, 144, 153, 154]
models = [0, 1, 64, 65, 128, 129, 576, 577, 640, 641, 704, 705, 1824, 1825, 1728, 1729, 1920, 1921]
create_dir("results/model_plots_microscope")
p_vals = []
m_vals = []
n_trials = 30
for i, pid in enumerate(control_pids):
    data = pd.DataFrame()
    m_data = {}
    diffs = []
    j = 0
    for model in models:
    #     for model in models:
        try:
            d = pickle_load(f"results/model_run_results_microscope/{pid}_mer_performance_error_{model}.pkl")
            data = data.append(d, ignore_index=True)
            mean_data = data.groupby(["algo", "x"]).mean()
            square = list(map(lambda x, y: (x-y)**2, mean_data['y']['algo'], mean_data['y']['participant']))
            p_val = mean_data['y']['participant'].values
            diff = np.sqrt(np.sum(square))
            diffs.append(diff)
            m_data[j] = mean_data
            j+=1
        except Exception as e:
            continue
    m_val = m_data[np.argmin(diffs)]["y"]["algo"].values
    if len(p_val) == n_trials and len(m_val) == n_trials:
        p_vals.append(p_val)
        m_vals.append(m_val)
#ax = sns.lineplot(x="x", y="y", hue = "algo", data=data)
plt.plot(range(1, len(p_val)+1), np.mean(p_vals, axis=0), label = "P") 
plt.plot(range(1, len(p_val)+1), np.mean(m_vals, axis=0), label = "M") 
plt.legend()
#plt.savefig(f"results/model_plots/{model}.png", bbox_inches='tight')
plt.show()

# %%
num_models = 3500
models = pd.read_csv("rl_models.csv")
rewards = []
for model_num in range(num_models):
    try:
        r = pickle_load(f"results/model_rewards/{model_num}.pkl")
#         if r < 30:
#             print(models.iloc[model_num].values, r)
        if r > 40:
            print(models.iloc[model_num].values, r)
        rewards.append(r)
    except:
        #print(models.iloc[model_num].values)
        continue
plt.hist(rewards)

# %%
from scipy.stats import loguniform
import numpy as np
import seaborn as sns
x = loguniform(0.01, 60)
rvs = x.rvs(100000)
sns.distplot(rvs)

# %%
num_p = 200
strategies = {}
temperatures = {}
for pid in range(num_p):
    try:
        S = pickle_load(f"results/final_strategy_inferences/v1.0_participant/{pid}_strategies.pkl")
        T = pickle_load(f"results/final_strategy_inferences/v1.0_participant/{pid}_temperatures.pkl")
        strategies[pid] = S
        temperatures[pid] = T
    except:
        continue
print(strategies, temperatures)
pickle_save(strategies, "results/final_strategy_inferences/v1.0_participant_strategies.pkl")
pickle_save(temperatures, "results/final_strategy_inferences/v1.0_participant_temperatures.pkl")
# Out:
# {0: [43, 43, 43, 43, 17, 67, 67, 43, 67, 42, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21], 1: [64, 64, 64, 64, 64, 64, 64, 64, 64, 63, 64, 64, 64, 64, 64, 64, 64, 64, 57, 57], 2: [23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22], 3: [23, 30, 23, 23, 23, 23, 23, 23, 23, 39, 39, 21, 21, 21, 21, 21, 21, 21, 21, 21], 4: [21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21], 5: [21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21], 6: [18, 18, 18, 18, 67, 67, 67, 67, 67, 67, 67, 67, 67, 67, 67, 67, 67, 67, 67, 67], 8: [30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30], 9: [17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17], 10: [21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 17, 17, 17, 17, 17], 11: [21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21], 12: [21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21], 13: [57, 57, 57, 57, 57, 57, 57, 57, 57, 57, 57, 57, 57, 57, 39, 88, 88, 88, 88, 88], 14: [21, 21, 21, 21, 21, 21, 21, 57, 57, 57, 57, 57, 57, 57, 57, 57, 57, 57, 57, 57], 15: [43, 43, 43, 43, 43, 43, 43, 43, 39, 39, 43, 43, 43, 21, 21, 21, 43, 43, 43, 43], 16: [11, 11, 11, 11, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21], 17: [21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21], 18: [18, 18, 18, 18, 18, 18, 18, 18, 18, 42, 42, 42, 42, 18, 18, 18, 18, 42, 42, 42], 19: [42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42], 20: [11, 11, 11, 11, 11, 11, 11, 76, 76, 76, 17, 17, 16, 16, 76, 76, 76, 14, 16, 16], 21: [21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21], 22: [30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30], 23: [31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31], 24: [21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21], 25: [87, 87, 87, 87, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21], 26: [57, 57, 57, 57, 57, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21], 27: [42, 42, 42, 42, 42, 42, 42, 67, 42, 42, 42, 67, 43, 43, 43, 17, 42, 21, 21, 21], 29: [57, 57, 57, 57, 57, 57, 57, 57, 57, 57, 57, 57, 57, 57, 57, 57, 57, 57, 57, 57], 30: [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 57, 57, 57, 26, 26, 26, 26, 26, 26, 26], 31: [21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21], 32: [65, 65, 65, 65, 65, 65, 65, 65, 65, 65, 65, 65, 65, 65, 65, 65, 65, 65, 65, 65], 33: [21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21], 34: [21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21], 35: [18, 42, 18, 18, 42, 18, 43, 43, 43, 43, 43, 43, 18, 43, 18, 18, 42, 42, 18, 18], 36: [21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21], 37: [43, 43, 43, 18, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 63, 63, 63], 38: [87, 87, 87, 87, 87, 87, 87, 87, 87, 87, 87, 87, 87, 87, 88, 88, 88, 88, 88, 88], 39: [30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30], 40: [22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22], 41: [11, 18, 39, 18, 18, 18, 16, 42, 76, 76, 76, 76, 29, 29, 18, 29, 76, 29, 29, 18], 42: [21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21], 43: [16, 16, 16, 16, 16, 16, 16, 16, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21], 44: [21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21], 45: [30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30], 47: [43, 43, 43, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21], 48: [57, 57, 57, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 87, 40, 40, 40], 49: [30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, ...

# %%
columns = ['model', 'decision_rule', 'use_pseudo_rewards', 'pr_weight', 'actor', 'term', 'selector', 'learner', 
            'strategy_space_type', 'stochastic_updating', 'subjective_cost', 'vicarious_learning', 'termination_value_known',
          'montecarlo_updates', 'is_null', 'is_gaussian', 'bandit_prior', 'prior']

# %%
# Hierarchical Learner
models =  ["hierarchical_learner"]
decision_rules = ["adaptive_satisficing", "threshold", "confidence_bound"]
prs = [True, False]
prws = [True, False]
actors = ["lvoc", "reinforce", "baseline_reinforce"]
term = [True, False]
selectors = [None]
learners = [None]
strategy_space_types = [None]
stochastic_updates = [None]
subjective_cost = [True, False]
vicarious_learning = [True, False]
termination_value_known = [True, False]
montecarlo_updates = [True, False]
is_null = [True, False]
is_gaussian = [None]
bandit_prior = [None]
priors = ["strategy_weight"]
ls = list(itertools.product(models, decision_rules, prs, prws, actors, term, selectors, learners, strategy_space_types, stochastic_updates,
                      subjective_cost, vicarious_learning, termination_value_known, montecarlo_updates, is_null, is_gaussian,
                      bandit_prior, priors))

# %%
print(len(ls))
# Out:
# 2304

# %%
# LVOC, REINFORCE and Baseline REINFORCE
models =  ["lvoc", "reinforce", "baseline_reinforce"]
decision_rules = [None]
prs = [True, False]
prws = [True, False]
actors = [None]
term = [True]
selectors = [None]
learners = [None]
strategy_space_types = [None]
stochastic_updates = [None]
subjective_cost = [True, False]
vicarious_learning = [True, False]
termination_value_known = [True, False]
montecarlo_updates = [True, False]
is_null = [True, False]
is_gaussian = [None]
bandit_prior = [None]
priors = ["strategy_weight"]
ls += list(itertools.product(models, decision_rules, prs, prws, actors, term, selectors, learners, strategy_space_types, stochastic_updates,
                      subjective_cost, vicarious_learning, termination_value_known, montecarlo_updates, is_null, is_gaussian,
                      bandit_prior, priors))

# %%
print(len(ls))
# Out:
# 2688

# %%
models =  ["rssl"]
decision_rules = [None]
prs = [True, False]
prws = [True, False]
actors = [None]
term = [None]
selectors = [None]
learners = [None]
strategy_space_types = ['microscope', 'participant']
stochastic_updates = [True, False]
subjective_cost = [None]
vicarious_learning = [None]
termination_value_known = [None]
montecarlo_updates = [None]
is_null = [True, False]
is_gaussian = [True, False]
bandit_prior = [None]
priors = ["bernoulli_prior", "gaussian_prior"] # Remove gaussian prior from bernoulli and bernoulli from gaussian
ls += list(itertools.product(models, decision_rules, prs, prws, actors, term, selectors, learners, strategy_space_types, stochastic_updates,
                      subjective_cost, vicarious_learning, termination_value_known, montecarlo_updates, is_null, is_gaussian,
                      bandit_prior, priors))
print(len(ls))
# Out:
# 2816

# %%
models =  ["sdss"]
decision_rules = [None]
prs = [True, False]
prws = [True, False]
actors = [None]
term = [True]
selectors = ["rssl"]
learners = ["lvoc", "reinforce", "baseline_reinforce"]
strategy_space_types = [None]
stochastic_updates = [True, False]
subjective_cost = [True, False]
vicarious_learning = [True, False]
termination_value_known = [True, False]
montecarlo_updates = [True, False]
is_null = [True, False]
is_gaussian = [True, False]
bandit_prior = [True]
priors = ["strategy_weight"]
ls += list(itertools.product(models, decision_rules, prs, prws, actors, term, selectors, learners, strategy_space_types, stochastic_updates,
                      subjective_cost, vicarious_learning, termination_value_known, montecarlo_updates, is_null, is_gaussian,
                      bandit_prior, priors))
print(len(ls))
# Out:
# 4352

# %%
import pandas as pd
df = pd.DataFrame(ls, columns = columns)

# %%
temp_df = df[df.is_gaussian == True][df.prior == "bernoulli_prior"].index
temp2_df = df[df.is_gaussian == False][df.prior == "gaussian_prior"].index
# Out:
# /anaconda3/envs/cogtut/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# /anaconda3/envs/cogtut/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
inds = temp_df.tolist() + temp2_df.tolist()
df.drop(inds, axis=0, inplace=True)

# %%
temp3 = df[(df.use_pseudo_rewards == False) & (df.pr_weight == True)]
print(temp3.index.tolist())
df.drop(temp3.index.tolist(), axis=0, inplace=True)
df.reset_index(drop=True, inplace=True)
# Out:
# [384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 395, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 406, 407, 408, 409, 410, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446, 447, 448, 449, 450, 451, 452, 453, 454, 455, 456, 457, 458, 459, 460, 461, 462, 463, 464, 465, 466, 467, 468, 469, 470, 471, 472, 473, 474, 475, 476, 477, 478, 479, 480, 481, 482, 483, 484, 485, 486, 487, 488, 489, 490, 491, 492, 493, 494, 495, 496, 497, 498, 499, 500, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 512, 513, 514, 515, 516, 517, 518, 519, 520, 521, 522, 523, 524, 525, 526, 527, 528, 529, 530, 531, 532, 533, 534, 535, 536, 537, 538, 539, 540, 541, 542, 543, 544, 545, 546, 547, 548, 549, 550, 551, 552, 553, 554, 555, 556, 557, 558, 559, 560, 561, 562, 563, 564, 565, 566, 567, 568, 569, 570, 571, 572, 573, 574, 575, 1152, 1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161, 1162, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171, 1172, 1173, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182, 1183, 1184, 1185, 1186, 1187, 1188, 1189, 1190, 1191, 1192, 1193, 1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1257, 1258, 1259, 1260, 1261, 1262, 1263, 1264, 1265, 1266, 1267, 1268, 1269, 1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287, 1288, 1289, 1290, 1291, 1292, 1293, 1294, 1295, 1296, 1297, 1298, 1299, 1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1316, 1317, 1318, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1329, 1330, 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1341, 1342, 1343, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047, 2048, 2049, 2050, 2051, 2052, 2053, 2054, 2055, 2056, 2057, 2058, 2059, 2060, 2061, 2062, 2063, 2064, 2065, 2066, 2067, 2068, 2069, 2070, 2071, 2072, 2073, 2074, 2075, 2076, 2077, 2078, 2079, 2080, 2081, 2082, 2083, 2084, 2085, 2086, 2087, 2088, 2089, 2090, 2091, 2092, 2093, 2094, 2095, 2096, 2097, 2098, 2099, 2100, 2101, 2102, 2103, 2104, 2105, 2106, 2107, 2108, 2109, 2110, 2111, 2368, 2369, 2370, 2371, 2372, 2373, 2374, 2375, 2376, 2377, 2378, 2379, 2380, 2381, 2382, 2383, 2384, 2385, 2386, 2387, 2388, 2389, 2390, 2391, 2392, 2393, 2394, 2395, 2396, 2397, 2398, 2399, 2496, 2497, 2498, 2499, 2500, 2501, 2502, 2503, 2504, 2505, 2506, 2507, 2508, 2509, 2510, 2511, 2512, 2513, 2514, 2515, 2516, 2517, 2518, 2519, 2520, 2521, 2522, 2523, 2524, 2525, 2526, 2527, 2624, 2625, 2626, 2627, 2628, 2629, 2630, 2631, 2632, 2633, 2634, 2635, 2636, 2637, 2638, 2639, 2640, 2641, 2642, 2643, 2644, 2645, 2646, 2647, 2648, 2649, 2650, 2651, 2652, 2653, 2654, 2655, 2753, 2754, 2757, 2758, 2761, 2762, 2765, 2766, 2769, 2770, 2773, 2774, 2777, 2778, 2781, 2782, 3584, 3585, 3586, 3587, 3588, 3589, 3590, 3591, 3592, 3593, 359 ...

# %%
print(len(df))
# Out:
# 3216

# %%
df.to_csv("rl_models.csv")
